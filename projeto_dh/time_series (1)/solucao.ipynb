# %% [markdown]
# ## Nessa aula vamos aprender como trabalhar em detalhes com séries temporais
#
# 1. Uma série temporal pode depender de outra série?
#     1. Se pedender como trabalhamos com essa dependência?
#
# 2. Como é feita a avaliação de uma série temporal?
#
# <img src="wfcv.png" />

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import lightgbm as lgb
import plotly.graph_objs as go

import optuna
import shap 

from sklearn.metrics import mean_squared_error

# %% [markdown]
# ### Aqui vamos tentar prever o preço das ações da Petrobrás

# %%
preco_pb = pd.read_csv('PETR4.SA.csv')
del preco_pb['Volume']
preco_pb.head()
# Out:
#          Date   Open   High    Low  Close  Adj Close
# 0  2015-07-02  12.35  12.53  12.16  12.35  11.457355
# 1  2015-07-03  12.25  12.31  11.68  11.76  10.909998
# 2  2015-07-06  11.51  11.73  11.28  11.51  10.678070
# 3  2015-07-07  11.36  11.85  10.82  11.77  10.919277
# 4  2015-07-08  11.62  11.99  11.33  11.46  10.631682

# %% [markdown]
# ### Vamos assumir que o preço da ação da empresa seja influenciado pelo preço do petroleo

# %%
preco_petro = pd.read_csv('CL=F.csv')
del preco_petro['Volume']
preco_petro.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close
# 0  2015-07-02  56.869999  57.950001  56.500000  56.930000  56.930000
# 1  2015-07-05        NaN        NaN        NaN        NaN        NaN
# 2  2015-07-06  54.900002  55.340000  52.410000  52.529999  52.529999
# 3  2015-07-07  52.750000  53.430000  50.580002  52.330002  52.330002
# 4  2015-07-08  52.910000  52.959999  50.910000  51.650002  51.650002

# %% [markdown]
# ### E o preço do real será que tem alguma influência?

# %%
preco_real = pd.read_csv('BR=F.csv')
del preco_real['Volume']
preco_real.head()
# Out:
#          Date     Open     High      Low    Close  Adj Close
# 0  2015-07-02  0.31890  0.31890  0.31890  0.31890    0.31890
# 1  2015-07-05      NaN      NaN      NaN      NaN        NaN
# 2  2015-07-06  0.31460  0.31460  0.31460  0.31460    0.31460
# 3  2015-07-07  0.31035  0.31200  0.30980  0.31035    0.31035
# 4  2015-07-08  0.30675  0.31075  0.30585  0.30675    0.30675

# %% [markdown]
# ### Vamos começar com alguns merges?

# %%
pb_petro = preco_pb.merge(preco_petro, on = 'Date', how = 'left')
pb_petro.head()
# Out:
#          Date  Open_x  High_x  Low_x  Close_x  Adj Close_x     Open_y  \
# 0  2015-07-02   12.35   12.53  12.16    12.35    11.457355  56.869999
# 1  2015-07-03   12.25   12.31  11.68    11.76    10.909998        NaN
# 2  2015-07-06   11.51   11.73  11.28    11.51    10.678070  54.900002
# 3  2015-07-07   11.36   11.85  10.82    11.77    10.919277  52.750000
# 4  2015-07-08   11.62   11.99  11.33    11.46    10.631682  52.910000
#
#       High_y      Low_y    Close_y  Adj Close_y
# 0  57.950001  56.500000  56.930000    56.930000
# 1        NaN        NaN        NaN          NaN
# 2  55.340000  52.410000  52.529999    52.529999
# 3  53.430000  50.580002  52.330002    52.330002
# 4  52.959999  50.910000  51.650002    51.650002

# %%
pb_petro_real = pb_petro.merge(preco_real, on = 'Date', how = 'left')
pb_petro_real.head()
# Out:
#          Date  Open_x  High_x  Low_x  Close_x  Adj Close_x     Open_y  \
# 0  2015-07-02   12.35   12.53  12.16    12.35    11.457355  56.869999
# 1  2015-07-03   12.25   12.31  11.68    11.76    10.909998        NaN
# 2  2015-07-06   11.51   11.73  11.28    11.51    10.678070  54.900002
# 3  2015-07-07   11.36   11.85  10.82    11.77    10.919277  52.750000
# 4  2015-07-08   11.62   11.99  11.33    11.46    10.631682  52.910000
#
#       High_y      Low_y    Close_y  Adj Close_y     Open     High      Low  \
# 0  57.950001  56.500000  56.930000    56.930000  0.31890  0.31890  0.31890
# 1        NaN        NaN        NaN          NaN      NaN      NaN      NaN
# 2  55.340000  52.410000  52.529999    52.529999  0.31460  0.31460  0.31460
# 3  53.430000  50.580002  52.330002    52.330002  0.31035  0.31200  0.30980
# 4  52.959999  50.910000  51.650002    51.650002  0.30675  0.31075  0.30585
#
#      Close  Adj Close
# 0  0.31890    0.31890
# 1      NaN        NaN
# 2  0.31460    0.31460
# 3  0.31035    0.31035
# 4  0.30675    0.30675

# %% [markdown]
# ### Renomear as colunas para facilitar nossa vida

# %%
nomes={ 'Date' : 'Data',
        "Open_x": "Preco_Abertura_Petrobras", 
        "High_x": "Preco_Alta_Petrobras",
        "Low_x": "Preco_Baixo_Petrobras",
        "Close_x": "Preco_Fechamento_Petrobras",
        "Adj Close_x" : "Preco_Corrigido_Petrobras",
        "Open_y": "Preco_Abertura_Petróleo", 
        "High_y": "Preco_Alta_Petróleo",
        "Low_y": "Preco_Baixo_Petróleo",
        "Close_y": "Preco_Fechamento_Petróleo",
        "Adj Close_y" : "Preco_Corrigido_Petróleo",
        "Open": "Preco_Abertura_Real", 
        "High": "Preco_Alta_Real",
        "Low": "Preco_Baixo_Real",
        "Close": "Preco_Fechamento_Real",
        "Adj Close" : "Preco_Corrigido_Real"}

pb_petro_real.rename(columns = nomes, inplace = True)
pb_petro_real.head()
# Out:
#          Data  Preco_Abertura_Petrobras  Preco_Alta_Petrobras  \
# 0  2015-07-02                     12.35                 12.53
# 1  2015-07-03                     12.25                 12.31
# 2  2015-07-06                     11.51                 11.73
# 3  2015-07-07                     11.36                 11.85
# 4  2015-07-08                     11.62                 11.99
#
#    Preco_Baixo_Petrobras  Preco_Fechamento_Petrobras  \
# 0                  12.16                       12.35
# 1                  11.68                       11.76
# 2                  11.28                       11.51
# 3                  10.82                       11.77
# 4                  11.33                       11.46
#
#    Preco_Corrigido_Petrobras  Preco_Abertura_Petróleo  Preco_Alta_Petróleo  \
# 0                  11.457355                56.869999            57.950001
# 1                  10.909998                      NaN                  NaN
# 2                  10.678070                54.900002            55.340000
# 3                  10.919277                52.750000            53.430000
# 4                  10.631682                52.910000            52.959999
#
#    Preco_Baixo_Petróleo  Preco_Fechamento_Petróleo  Preco_Corrigido_Petróleo  \
# 0             56.500000                  56.930000                 56.930000
# 1                   NaN                        NaN                       NaN
# 2             52.410000                  52.529999                 52.529999
# 3             50.580002                  52.330002                 52.330002
# 4             50.910000                  51.650002                 51.650002
#
#    Preco_Abertura_Real  Preco_Alta_Real  Preco_Baixo_Real  \
# 0              0.31890          0.31890           0.31890
# 1                  NaN              NaN               NaN
# 2              0.31460          0.31460           0.31460
# 3              0.31035          0.31200           0.30980
# 4              0.30675          0.31075           0.30585
#
#    Preco_Fechamento_Real  Preco_Corrigido_Real
# 0                0.31890               0.31890
# 1                    NaN                   NaN
# 2                0.31460               0.31460
# 3                0.31035               0.31035
# 4                0.30675               0.30675

# %%
pb_petro_real.dtypes
# Out:
# Data                           object
# Preco_Abertura_Petrobras      float64
# Preco_Alta_Petrobras          float64
# Preco_Baixo_Petrobras         float64
# Preco_Fechamento_Petrobras    float64
# Preco_Corrigido_Petrobras     float64
# Preco_Abertura_Petróleo       float64
# Preco_Alta_Petróleo           float64
# Preco_Baixo_Petróleo          float64
# Preco_Fechamento_Petróleo     float64
# Preco_Corrigido_Petróleo      float64
# Preco_Abertura_Real           float64
# Preco_Alta_Real               float64
# Preco_Baixo_Real              float64
# Preco_Fechamento_Real         float64
# Preco_Corrigido_Real          float64
# dtype: object

# %%
#Lembre de sempre definir a coluna que contém a data como datetime
pb_petro_real['Data'] = pd.to_datetime(pb_petro_real['Data'])

pb_petro_real.dtypes
# Out:
# Data                          datetime64[ns]
# Preco_Abertura_Petrobras             float64
# Preco_Alta_Petrobras                 float64
# Preco_Baixo_Petrobras                float64
# Preco_Fechamento_Petrobras           float64
# Preco_Corrigido_Petrobras            float64
# Preco_Abertura_Petróleo              float64
# Preco_Alta_Petróleo                  float64
# Preco_Baixo_Petróleo                 float64
# Preco_Fechamento_Petróleo            float64
# Preco_Corrigido_Petróleo             float64
# Preco_Abertura_Real                  float64
# Preco_Alta_Real                      float64
# Preco_Baixo_Real                     float64
# Preco_Fechamento_Real                float64
# Preco_Corrigido_Real                 float64
# dtype: object

# %%
## separar a variável alvo

y = pb_petro_real['Preco_Corrigido_Petrobras']
del pb_petro_real['Preco_Corrigido_Petrobras']

colunas = pb_petro_real.select_dtypes(exclude=['datetime64']).columns.tolist()

# %%
janela=30
for i in range (0, len(colunas)):
    pb_petro_real[str(colunas[i]+'_Media')] = pb_petro_real[str(colunas[i])].\
            rolling(window=janela).mean().round(4)

for i in range (0, len(colunas)):
    pb_petro_real[str(colunas[i]+'_%')] = pb_petro_real[str(colunas[i])].pct_change(janela-1).round(4)

# %%
pb_petro_real[29:32].T
# Out:
#                                                    29                   30  \
# Data                              2015-08-13 00:00:00  2015-08-14 00:00:00
# Preco_Abertura_Petrobras                         9.91                 9.61
# Preco_Alta_Petrobras                             9.97                 9.68
# Preco_Baixo_Petrobras                             9.5                  9.3
# Preco_Fechamento_Petrobras                        9.5                  9.3
# Preco_Abertura_Petróleo                         43.34                42.23
# Preco_Alta_Petróleo                             43.72                42.96
# Preco_Baixo_Petróleo                            41.91                41.35
# Preco_Fechamento_Petróleo                       42.23                 42.5
# Preco_Corrigido_Petróleo                        42.23                 42.5
# Preco_Abertura_Real                            0.2831               0.2858
# Preco_Alta_Real                                 0.285               0.2872
# Preco_Baixo_Real                               0.2817              0.28255
# Preco_Fechamento_Real                          0.2831               0.2858
# Preco_Corrigido_Real                           0.2831               0.2858
# Preco_Abertura_Petrobras_Media                10.8297              10.7383
# Preco_Alta_Petrobras_Media                     11.053               10.958
# Preco_Baixo_Petrobras_Media                   10.5313               10.436
# Preco_Fechamento_Petrobras_Media              10.7433              10.6417
# Preco_Abertura_Petróleo_Media                     NaN                  NaN
# Preco_Alta_Petróleo_Media                         NaN                  NaN
# Preco_Baixo_Petróleo_Media                        NaN                  NaN
# Preco_Fechamento_Petróleo_Media                   NaN                  NaN
# Preco_Corrigido_Petróleo_Media                    NaN                  NaN
# Preco_Abertura_Real_Media                         NaN                  NaN
# Preco_Alta_Real_Media                             NaN                  NaN
# Preco_Baixo_Real_Media                            NaN                  NaN
# Preco_Fechamento_Real_Media                       NaN                  NaN
# Preco_Corrigido_Real_Media                        NaN                  NaN
# Preco_Abertura_Petrobras_%                    -0.1976              -0.2155
# Preco_Alta_Petrobras_%                        -0.2043              -0.2136
# Preco_Baixo_Petrobras_%                       -0.2188              -0.2038
# Preco_Fechamento_Petrobras_%                  -0.2308              -0.2092
# Preco_Abertura_Petróleo_%                     -0.2379              -0.2574
# Preco_Alta_Petróleo_%                         -0.2456              -0.2587
# Preco_Baixo_Petróleo_%                        -0.2582              -0.2681
# Preco_Fechamento_Petróleo_%                   -0.2582              -0.2535
# Preco_Corrigido_Petróleo_%                    -0.2582              -0.2535
# Preco_Abertura_Real_%                         -0.1123              -0.1038
# Preco_Alta_Real_%                             -0.1063              -0.0994
# Preco_Baixo_Real_%                            -0.1167               -0.114
# Preco_Fechamento_Real_%                       -0.1123              -0.1038
# Preco_Corrigido_Real_%                        -0.1123              -0.1038
#
#                                                    31
# Data                              2015-08-17 00:00:00
# Preco_Abertura_Petrobras                          9.2
# Preco_Alta_Petrobras                             9.36
# Preco_Baixo_Petrobras                            9.12
# Preco_Fechamento_Petrobras                       9.15
# Preco_Abertura_Petróleo                         42.18
# Preco_Alta_Petróleo                             42.69
# Preco_Baixo_Petróleo                            41.64
# Preco_Fechamento_Petróleo                       41.87
# Preco_Corrigido_Petróleo                        41.87
# Preco_Abertura_Real                           0.28565
# Preco_Alta_Real                                0.2873
# Preco_Baixo_Real                              0.28375
# Preco_Fechamento_Real                         0.28565
# Preco_Corrigido_Real                          0.28565
# Preco_Abertura_Petrobras_Media                10.6367
# Preco_Alta_Petrobras_Media                    10.8597
# Preco_Baixo_Petrobras_Media                   10.3507
# Preco_Fechamento_Petrobras_Media              10.5547
# Preco_Abertura_Petróleo_Media                 48.3417
# Preco_Alta_Petróleo_Media                       48.96
# Preco_Baixo_Petróleo_Media                    47.2547
# Preco_Fechamento_Petróleo_Media               47.8773
# Preco_Corrigido_Petróleo_Media                47.8773
# Preco_Abertura_Real_Media                       0.299
# Preco_Alta_Real_Media                           0.301
# Preco_Baixo_Real_Media                          0.297
# Preco_Fechamento_Real_Media                     0.299
# Preco_Corrigido_Real_Media                      0.299
# Preco_Abertura_Petrobras_%                    -0.2007
# Preco_Alta_Petrobras_%                         -0.202
# Preco_Baixo_Petrobras_%                       -0.1915
# Preco_Fechamento_Petrobras_%                   -0.205
# Preco_Abertura_Petróleo_%                     -0.2317
# Preco_Alta_Petróleo_%                         -0.2286
# Preco_Baixo_Petróleo_%                        -0.2055
# Preco_Fechamento_Petróleo_%                   -0.2029
# Preco_Corrigido_Petróleo_%                    -0.2029
# Preco_Abertura_Real_%                          -0.092
# Preco_Alta_Real_%                             -0.0868
# Preco_Baixo_Real_%                            -0.0981
# Preco_Fechamento_Real_%                        -0.092
# Preco_Corrigido_Real_%                         -0.092

# %%
for i in range (0, len(colunas)):
    for j in range (int(i+1), len(colunas)):

        pb_petro_real['Correlacao_'+colunas[i]+colunas[j]] = \
            pb_petro_real[colunas[i]].rolling(window=janela).corr(pb_petro_real[colunas[j]]).round(4)

# %%
pb_petro_real[29:32].T
# Out:
#                                                                      29  \
# Data                                                2015-08-13 00:00:00
# Preco_Abertura_Petrobras                                           9.91
# Preco_Alta_Petrobras                                               9.97
# Preco_Baixo_Petrobras                                               9.5
# Preco_Fechamento_Petrobras                                          9.5
# ...                                                                 ...
# Correlacao_Preco_Alta_RealPreco_Fechamento_Real                     NaN
# Correlacao_Preco_Alta_RealPreco_Corrigido_Real                      NaN
# Correlacao_Preco_Baixo_RealPreco_Fechamento_Real                    NaN
# Correlacao_Preco_Baixo_RealPreco_Corrigido_Real                     NaN
# Correlacao_Preco_Fechamento_RealPreco_Corrigido...                  NaN
#
#                                                                      30  \
# Data                                                2015-08-14 00:00:00
# Preco_Abertura_Petrobras                                           9.61
# Preco_Alta_Petrobras                                               9.68
# Preco_Baixo_Petrobras                                               9.3
# Preco_Fechamento_Petrobras                                          9.3
# ...                                                                 ...
# Correlacao_Preco_Alta_RealPreco_Fechamento_Real                     NaN
# Correlacao_Preco_Alta_RealPreco_Corrigido_Real                      NaN
# Correlacao_Preco_Baixo_RealPreco_Fechamento_Real                    NaN
# Correlacao_Preco_Baixo_RealPreco_Corrigido_Real                     NaN
# Correlacao_Preco_Fechamento_RealPreco_Corrigido...                  NaN
#
#                                                                      31
# Data                                                2015-08-17 00:00:00
# Preco_Abertura_Petrobras                                            9.2
# Preco_Alta_Petrobras                                               9.36
# Preco_Baixo_Petrobras                                              9.12
# Preco_Fechamento_Petrobras                                         9.15
# ...                                                                 ...
# Correlacao_Preco_Alta_RealPreco_Fechamento_Real                  0.9945
# Correlacao_Preco_Alta_RealPreco_Corrigido_Real                   0.9945
# Correlacao_Preco_Baixo_RealPreco_Fechamento_Real                 0.9935
# Correlacao_Preco_Baixo_RealPreco_Corrigido_Real                  0.9935
# Correlacao_Preco_Fechamento_RealPreco_Corrigido...                    1
#
# [134 rows x 3 columns]

# %%
colunas2 = pb_petro_real.select_dtypes(exclude=['datetime64']).columns.tolist()

# %%
for i in range (0, len(colunas2)):
    pb_petro_real[colunas2[i]] = pb_petro_real[colunas2[i]].shift(periods=janela)

# %%
pd.options.display.max_rows = None
pb_petro_real[29:32].T
# Out:
#                                                            29  \
# Data                                               2015-08-13
# Preco_Abertura_Petrobras                                  NaT
# Preco_Alta_Petrobras                                      NaT
# Preco_Baixo_Petrobras                                     NaT
# Preco_Fechamento_Petrobras                                NaT
# Preco_Abertura_Petróleo                                   NaT
# Preco_Alta_Petróleo                                       NaT
# Preco_Baixo_Petróleo                                      NaT
# Preco_Fechamento_Petróleo                                 NaT
# Preco_Corrigido_Petróleo                                  NaT
# Preco_Abertura_Real                                       NaT
# Preco_Alta_Real                                           NaT
# Preco_Baixo_Real                                          NaT
# Preco_Fechamento_Real                                     NaT
# Preco_Corrigido_Real                                      NaT
# Preco_Abertura_Petrobras_Media                            NaT
# Preco_Alta_Petrobras_Media                                NaT
# Preco_Baixo_Petrobras_Media                               NaT
# Preco_Fechamento_Petrobras_Media                          NaT
# Preco_Abertura_Petróleo_Media                             NaT
# Preco_Alta_Petróleo_Media                                 NaT
# Preco_Baixo_Petróleo_Media                                NaT
# Preco_Fechamento_Petróleo_Media                           NaT
# Preco_Corrigido_Petróleo_Media                            NaT
# Preco_Abertura_Real_Media                                 NaT
# Preco_Alta_Real_Media                                     NaT
# Preco_Baixo_Real_Media                                    NaT
# Preco_Fechamento_Real_Media                               NaT
# Preco_Corrigido_Real_Media                                NaT
# Preco_Abertura_Petrobras_%                                NaT
# Preco_Alta_Petrobras_%                                    NaT
# Preco_Baixo_Petrobras_%                                   NaT
# Preco_Fechamento_Petrobras_%                              NaT
# Preco_Abertura_Petróleo_%                                 NaT
# Preco_Alta_Petróleo_%                                     NaT
# Preco_Baixo_Petróleo_%                                    NaT
# Preco_Fechamento_Petróleo_%                               NaT
# Preco_Corrigido_Petróleo_%                                NaT
# Preco_Abertura_Real_%                                     NaT
# Preco_Alta_Real_%                                         NaT
# Preco_Baixo_Real_%                                        NaT
# Preco_Fechamento_Real_%                                   NaT
# Preco_Corrigido_Real_%                                    NaT
# Correlacao_Preco_Abertura_PetrobrasPreco_Alta_P...        NaT
# Correlacao_Preco_Abertura_PetrobrasPreco_Baixo_...        NaT
# Correlacao_Preco_Abertura_PetrobrasPreco_Fecham...        NaT
# Correlacao_Preco_Abertura_PetrobrasPreco_Abertu...        NaT
# Correlacao_Preco_Abertura_PetrobrasPreco_Alta_P...        NaT
# Correlacao_Preco_Abertura_PetrobrasPreco_Baixo_...        NaT
# Correlacao_Preco_Abertura_PetrobrasPreco_Fecham...        NaT
# Correlacao_Preco_Abertura_PetrobrasPreco_Corrig...        NaT
# Correlacao_Preco_Abertura_PetrobrasPreco_Abertu...        NaT
# Correlacao_Preco_Abertura_PetrobrasPreco_Alta_Real        NaT
# Correlacao_Preco_Abertura_PetrobrasPreco_Baixo_...        NaT
# Correlacao_Preco_Abertura_PetrobrasPreco_Fecham...        NaT
# Correlacao_Preco_Abertura_PetrobrasPreco_Corrig...        NaT
# Correlacao_Preco_Alta_PetrobrasPreco_Baixo_Petr...        NaT
# Correlacao_Preco_Alta_PetrobrasPreco_Fechamento...        NaT
# Correlacao_Preco_Alta_PetrobrasPreco_Abertura_P...        NaT
# Correlacao_Preco_Alta_PetrobrasPreco_Alta_Petróleo        NaT
# Correlacao_Preco_Alta_PetrobrasPreco_Baixo_Petr...        NaT
# Correlacao_Preco_Alta_PetrobrasPreco_Fechamento...        NaT
# Correlacao_Preco_Alta_PetrobrasPreco_Corrigido_...        NaT
# Correlacao_Preco_Alta_PetrobrasPreco_Abertura_Real        NaT
# Correlacao_Preco_Alta_PetrobrasPreco_Alta_Real            NaT
# Correlacao_Preco_Alta_PetrobrasPreco_Baixo_Real           NaT
# Correlacao_Preco_Alta_PetrobrasPreco_Fechamento...        NaT
# Correlacao_Preco_Alta_PetrobrasPreco_Corrigido_...        NaT
# Correlacao_Preco_Baixo_PetrobrasPreco_Fechament...        NaT
# Correlacao_Preco_Baixo_PetrobrasPreco_Abertura_...        NaT
# Correlacao_Preco_Baixo_PetrobrasPreco_Alta_Petr...        NaT
# Correlacao_Preco_Baixo_PetrobrasPreco_Baixo_Pet...        NaT
# Correlacao_Preco_Baixo_PetrobrasPreco_Fechament...        NaT
# Correlacao_Preco_Baixo_PetrobrasPreco_Corrigido...        NaT
# Correlacao_Preco_Baixo_PetrobrasPreco_Abertura_...        NaT
# Correlacao_Preco_Baixo_PetrobrasPreco_Alta_Real           NaT
# Correlacao_Preco_Baixo_PetrobrasPreco_Baixo_Real          NaT
# Correlacao_Preco_Baixo_PetrobrasPreco_Fechament...        NaT
# Correlacao_Preco_Baixo_PetrobrasPreco_Corrigido...        NaT
# Correlacao_Preco_Fechamento_PetrobrasPreco_Aber...        NaT
# Correlacao_Preco_Fechamento_PetrobrasPreco_Alta...        NaT
# Correlacao_Preco_Fechamento_PetrobrasPreco_Baix...        NaT
# Correlacao_Preco_Fechamento_PetrobrasPreco_Fech...        NaT
# Correlacao_Preco_Fechamento_PetrobrasPreco_Corr...        NaT
# Correlacao_Preco_Fechamento_PetrobrasPreco_Aber...        NaT
# Correlacao_Preco_Fechamento_PetrobrasPreco_Alta...        NaT
# Correlacao_Preco_Fechamento_PetrobrasPreco_Baix...        NaT
# Correlacao_Preco_Fechamento_PetrobrasPreco_Fech...        NaT
# Correlacao_Preco_Fechamento_PetrobrasPreco_Corr...        NaT
# Correlacao_Preco_Abertura_PetróleoPreco_Alta_Pe...        NaT
# Correlacao_Preco_Abertura_PetróleoPreco_Baixo_P...        NaT
# Correlacao_Preco_Abertura_PetróleoPreco_Fechame...        NaT
# Correlacao_Preco_Abertura_PetróleoPreco_Corrigi...        NaT
# Correlacao_Preco_Abertura_PetróleoPreco_Abertur...        NaT
# Correlacao_Preco_Abertura_PetróleoPreco_Alta_Real         NaT
# Correlacao_Preco_Abertura_PetróleoPreco_Baixo_Real        NaT
# Correlacao_Preco_Abertura_PetróleoPreco_Fechame...        NaT
# Correlacao_Preco_Abertura_PetróleoPreco_Corrigi...        NaT
# Correlacao_Preco_Alta_PetróleoPreco_Baixo_Petróleo        NaT
# Correlacao_Preco_Alta_PetróleoPreco_Fechamento_...        NaT
# Correlacao_Preco_Alta_PetróleoPreco_Corrigido_P...        NaT
# Correlacao_Preco_Alta_PetróleoPreco_Abertura_Real         NaT
# Correlacao_Preco_Alta_PetróleoPreco_Alta_Real             NaT
# Correlacao_Preco_Alta_PetróleoPreco_Baixo_Real            NaT
# Correlacao_Preco_Alta_PetróleoPreco_Fechamento_...        NaT
# Correlacao_Preco_Alta_PetróleoPreco_Corrigido_Real        NaT
# Correlacao_Preco_Baixo_PetróleoPreco_Fechamento...        NaT
# Correlacao_Preco_Baixo_PetróleoPreco_Corrigido_...        NaT
# Correlacao_Preco_Baixo_PetróleoPreco_Abertura_Real        NaT
# Correlacao_Preco_Baixo_PetróleoPreco_Alta_Real            NaT
# Correlacao_Preco_Baixo_PetróleoPreco_Baixo_Real           NaT
# Correlacao_Preco_Baixo_PetróleoPreco_Fechamento...        NaT
# Correlacao_Preco_Baixo_PetróleoPreco_Corrigido_...        NaT
# Correlacao_Preco_Fechamento_PetróleoPreco_Corri...        NaT
# Correlacao_Preco_Fechamento_PetróleoPreco_Abert...        NaT
# Correlacao_Preco_Fechamento_PetróleoPreco_Alta_...        NaT
# Correlacao_Preco_Fechamento_PetróleoPreco_Baixo...        NaT
# Correlacao_Preco_Fechamento_PetróleoPreco_Fecha...        NaT
# Correlacao_Preco_Fechamento_PetróleoPreco_Corri...        NaT
# Correlacao_Preco_Corrigido_PetróleoPreco_Abertu...        NaT
# Correlacao_Preco_Corrigido_PetróleoPreco_Alta_Real        NaT
# Correlacao_Preco_Corrigido_PetróleoPreco_Baixo_...        NaT
# Correlacao_Preco_Corrigido_PetróleoPreco_Fecham...        NaT
# Correlacao_Preco_Corrigido_PetróleoPreco_Corrig...        NaT
# Correlacao_Preco_Abertura_RealPreco_Alta_Real             NaT
# Correlacao_Preco_Abertura_RealPreco_Baixo_Real            NaT
# Correlacao_Preco_Abertura_RealPreco_Fechamento_...        NaT
# Correlacao_Preco_Abertura_RealPreco_Corrigido_Real        NaT
# Correlacao_Preco_Alta_RealPreco_Baixo_Real                NaT
# Correlacao_Preco_Alta_RealPreco_Fechamento_Real           NaT
# Correlacao_Preco_Alta_RealPreco_Corrigido_Real            NaT
# Correlacao_Preco_Baixo_RealPreco_Fechamento_Real          NaT
# Correlacao_Preco_Baixo_RealPreco_Corrigido_Real           NaT
# Correlacao_Preco_Fechamento_RealPreco_Corrigido...        NaT
#
#                                                                      30  \
# Data                                                2015-08-14 00:00:00
# Preco_Abertura_Petrobras                                          12.35
# Preco_Alta_Petrobras                                              12.53
# Preco_Baixo_Petrobras                                             12.16
# Preco_Fechamento_Petrobras                                        12.35
# Preco_Abertura_Petróleo                                           56.87
# Preco_Alta_Petróleo                                               57.95
# Preco_Baixo_Petróleo                                               56.5
# Preco_Fechamento_Petróleo                                         56.93
# Preco_Corrigido_Petróleo                                          56.93
# Preco_Abertura_Real                                              0.3189
# Preco_Alta_Real                                                  0.3189
# Preco_Baixo_Real                                                 0.3189
# Preco_Fechamento_Real                                            0.3189
# Preco_Corrigido_Real                                             0.3189
# Preco_Abertura_Petrobras_Media                                      NaN
# Preco_Alta_Petrobras_Media                                          NaN
# Preco_Baixo_Petrobras_Media                                         NaN
# Preco_Fechamento_Petrobras_Media                                    NaN
# Preco_Abertura_Petróleo_Media                                       NaN
# Preco_Alta_Petróleo_Media                                           NaN
# Preco_Baixo_Petróleo_Media                                          NaN
# Preco_Fechamento_Petróleo_Media                                     NaN
# Preco_Corrigido_Petróleo_Media                                      NaN
# Preco_Abertura_Real_Media                                           NaN
# Preco_Alta_Real_Media                                               NaN
# Preco_Baixo_Real_Media                                              NaN
# Preco_Fechamento_Real_Media                                         NaN
# Preco_Corrigido_Real_Media                                          NaN
# Preco_Abertura_Petrobras_%                                          NaN
# Preco_Alta_Petrobras_%                                              NaN
# Preco_Baixo_Petrobras_%                                             NaN
# Preco_Fechamento_Petrobras_%                                        NaN
# Preco_Abertura_Petróleo_%                                           NaN
# Preco_Alta_Petróleo_%                                               NaN
# Preco_Baixo_Petróleo_%                                              NaN
# Preco_Fechamento_Petróleo_%                                         NaN
# Preco_Corrigido_Petróleo_%                                          NaN
# Preco_Abertura_Real_%                                               NaN
# Preco_Alta_Real_%                                                   NaN
# Preco_Baixo_Real_%                                                  NaN
# Preco_Fechamento_Real_%                                             NaN
# Preco_Corrigido_Real_%                                              NaN
# Correlacao_Preco_Abertura_PetrobrasPreco_Alta_P...                  NaN
# Correlacao_Preco_Abertura_PetrobrasPreco_Baixo_...                  NaN
# Correlacao_Preco_Abertura_PetrobrasPreco_Fecham...                  NaN
# Correlacao_Preco_Abertura_PetrobrasPreco_Abertu...                  NaN
# Correlacao_Preco_Abertura_PetrobrasPreco_Alta_P...                  NaN
# Correlacao_Preco_Abertura_PetrobrasPreco_Baixo_...                  NaN
# Correlacao_Preco_Abertura_PetrobrasPreco_Fecham...                  NaN
# Correlacao_Preco_Abertura_PetrobrasPreco_Corrig...                  NaN
# Correlacao_Preco_Abertura_PetrobrasPreco_Abertu...                  NaN
# Correlacao_Preco_Abertura_PetrobrasPreco_Alta_Real                  NaN
# Correlacao_Preco_Abertura_PetrobrasPreco_Baixo_...                  NaN
# Correlacao_Preco_Abertura_PetrobrasPreco_Fecham...                  NaN
# Correlacao_Preco_Abertura_PetrobrasPreco_Corrig...                  NaN
# Correlacao_Preco_Alta_PetrobrasPreco_Baixo_Petr...                  NaN
# Correlacao_Preco_Alta_PetrobrasPreco_Fechamento...                  NaN
# Correlacao_Preco_Alta_PetrobrasPreco_Abertura_P...                  NaN
# Correlacao_Preco_Alta_PetrobrasPreco_Alta_Petróleo                  NaN
# Correlacao_Preco_Alta_PetrobrasPreco_Baixo_Petr...                  NaN
# Correlacao_Preco_Alta_PetrobrasPreco_Fechamento...                  NaN
# Correlacao_Preco_Alta_PetrobrasPreco_Corrigido_...                  NaN
# Correlacao_Preco_Alta_PetrobrasPreco_Abertura_Real                  NaN
# Correlacao_Preco_Alta_PetrobrasPreco_Alta_Real                      NaN
# Correlacao_Preco_Alta_PetrobrasPreco_Baixo_Real                     NaN
# Correlacao_Preco_Alta_PetrobrasPreco_Fechamento...                  NaN
# Correlacao_Preco_Alta_PetrobrasPreco_Corrigido_...                  NaN
# Correlacao_Preco_Baixo_PetrobrasPreco_Fechament...                  NaN
# Correlacao_Preco_Baixo_PetrobrasPreco_Abertura_...                  NaN
# Correlacao_Preco_Baixo_PetrobrasPreco_Alta_Petr...                  NaN
# Correlacao_Preco_Baixo_PetrobrasPreco_Baixo_Pet...                  NaN
# Correlacao_Preco_Baixo_PetrobrasPreco_Fechament...                  NaN
# Correlacao_Preco_Baixo_PetrobrasPreco_Corrigido...                  NaN
# Correlacao_Preco_Baixo_PetrobrasPreco_Abertura_...                  NaN
# Correlacao_Preco_Baixo_PetrobrasPreco_Alta_Real                     NaN
# Correlacao_Preco_Baixo_PetrobrasPreco_Baixo_Real                    NaN
# Correlacao_Preco_Baixo_PetrobrasPreco_Fechament...                  NaN
# Correlacao_Preco_Baixo_PetrobrasPreco_Corrigido...                  NaN
# Correlacao_Preco_Fechamento_PetrobrasPreco_Aber...                  NaN
# Correlacao_Preco_Fechamento_PetrobrasPreco_Alta...                  NaN
# Correlacao_Preco_Fechamento_PetrobrasPreco_Baix...                  NaN
# Correlacao_Preco_Fechamento_PetrobrasPreco_Fech...                  NaN
# Correlacao_Preco_Fechamento_PetrobrasPreco_Corr...                  NaN
# Correlacao_Preco_Fechamento_PetrobrasPreco_Aber...                  NaN
# Correlacao_Preco_Fechamento_PetrobrasPreco_Alta...                  NaN
# Correlacao_Preco_Fechamento_PetrobrasPreco_Baix...                  NaN
# Correlacao_Preco_Fechamento_PetrobrasPreco_Fech...                  NaN
# Correlacao_Preco_Fechamento_PetrobrasPreco_Corr...                  NaN
# Correlacao_Preco_Abertura_PetróleoPreco_Alta_Pe...                  NaN
# Correlacao_Preco_Abertura_PetróleoPreco_Baixo_P...                  NaN
# Correlacao_Preco_Abertura_PetróleoPreco_Fechame...                  NaN
# Correlacao_Preco_Abertura_PetróleoPreco_Corrigi...                  NaN
# Correlacao_Preco_Abertura_PetróleoPreco_Abertur...                  NaN
# Correlacao_Preco_Abertura_PetróleoPreco_Alta_Real                   NaN
# Correlacao_Preco_Abertura_PetróleoPreco_Baixo_Real                  NaN
# Correlacao_Preco_Abertura_PetróleoPreco_Fechame...                  NaN
# Correlacao_Preco_Abertura_PetróleoPreco_Corrigi...                  NaN
# Correlacao_Preco_Alta_PetróleoPreco_Baixo_Petróleo                  NaN
# Correlacao_Preco_Alta_PetróleoPreco_Fechamento_...                  NaN
# Correlacao_Preco_Alta_PetróleoPreco_Corrigido_P...                  NaN
# Correlacao_Preco_Alta_PetróleoPreco_Abertura_Real                   NaN
# Correlacao_Preco_Alta_PetróleoPreco_Alta_Real                       NaN
# Correlacao_Preco_Alta_PetróleoPreco_Baixo_Real                      NaN
# Correlacao_Preco_Alta_PetróleoPreco_Fechamento_...                  NaN
# Correlacao_Preco_Alta_PetróleoPreco_Corrigido_Real                  NaN
# Correlacao_Preco_Baixo_PetróleoPreco_Fechamento...                  NaN
# Correlacao_Preco_Baixo_PetróleoPreco_Corrigido_...                  NaN
# Correlacao_Preco_Baixo_PetróleoPreco_Abertura_Real                  NaN
# Correlacao_Preco_Baixo_PetróleoPreco_Alta_Real                      NaN
# Correlacao_Preco_Baixo_PetróleoPreco_Baixo_Real                     NaN
# Correlacao_Preco_Baixo_PetróleoPreco_Fechamento...                  NaN
# Correlacao_Preco_Baixo_PetróleoPreco_Corrigido_...                  NaN
# Correlacao_Preco_Fechamento_PetróleoPreco_Corri...                  NaN
# Correlacao_Preco_Fechamento_PetróleoPreco_Abert...                  NaN
# Correlacao_Preco_Fechamento_PetróleoPreco_Alta_...                  NaN
# Correlacao_Preco_Fechamento_PetróleoPreco_Baixo...                  NaN
# Correlacao_Preco_Fechamento_PetróleoPreco_Fecha...                  NaN
# Correlacao_Preco_Fechamento_PetróleoPreco_Corri...                  NaN
# Correlacao_Preco_Corrigido_PetróleoPreco_Abertu...                  NaN
# Correlacao_Preco_Corrigido_PetróleoPreco_Alta_Real                  NaN
# Correlacao_Preco_Corrigido_PetróleoPreco_Baixo_...                  NaN
# Correlacao_Preco_Corrigido_PetróleoPreco_Fecham...                  NaN
# Correlacao_Preco_Corrigido_PetróleoPreco_Corrig...                  NaN
# Correlacao_Preco_Abertura_RealPreco_Alta_Real                       NaN
# Correlacao_Preco_Abertura_RealPreco_Baixo_Real                      NaN
# Correlacao_Preco_Abertura_RealPreco_Fechamento_...                  NaN
# Correlacao_Preco_Abertura_RealPreco_Corrigido_Real                  NaN
# Correlacao_Preco_Alta_RealPreco_Baixo_Real                          NaN
# Correlacao_Preco_Alta_RealPreco_Fechamento_Real                     NaN
# Correlacao_Preco_Alta_RealPreco_Corrigido_Real                      NaN
# Correlacao_Preco_Baixo_RealPreco_Fechamento_Real                    NaN
# Correlacao_Preco_Baixo_RealPreco_Corrigido_Real                     NaN
# Correlacao_Preco_Fechamento_RealPreco_Corrigido...                  NaN
#
#                                                                      31
# Data                                                2015-08-17 00:00:00
# Preco_Abertura_Petrobras                                          12.25
# Preco_Alta_Petrobras                                              12.31
# Preco_Baixo_Petrobras                                             11.68
# Preco_Fechamento_Petrobras                                        11.76
# Preco_Abertura_Petróleo                                             NaN
# Preco_Alta_Petróleo                                                 NaN
# Preco_Baixo_Petróleo                                                NaN
# Preco_Fechamento_Petróleo                                           NaN
# Preco_Corrigido_Petróleo                                            NaN
# Preco_Abertura_Real                                                 NaN
# Preco_Alta_Real                                                     NaN
# Preco_Baixo_Real                                                    NaN
# Preco_Fechamento_Real                                               NaN
# Preco_Corrigido_Real                                                NaN
# Preco_Abertura_Petrobras_Media                                      NaN
# Preco_Alta_Petrobras_Media                                          NaN
# Preco_Baixo_Petrobras_Media                                         NaN
# Preco_Fechamento_Petrobras_Media                                    NaN
# Preco_Abertura_Petróleo_Media                                       NaN
# Preco_Alta_Petróleo_Media                                           NaN
# Preco_Baixo_Petróleo_Media                                          NaN
# Preco_Fechamento_Petróleo_Media                                     NaN
# Preco_Corrigido_Petróleo_Media                                      NaN
# Preco_Abertura_Real_Media                                           NaN
# Preco_Alta_Real_Media                                               NaN
# Preco_Baixo_Real_Media                                              NaN
# Preco_Fechamento_Real_Media                                         NaN
# Preco_Corrigido_Real_Media                                          NaN
# Preco_Abertura_Petrobras_%                                          NaN
# Preco_Alta_Petrobras_%                                              NaN
# Preco_Baixo_Petrobras_%                                             NaN
# Preco_Fechamento_Petrobras_%                                        NaN
# Preco_Abertura_Petróleo_%                                           NaN
# Preco_Alta_Petróleo_%                                               NaN
# Preco_Baixo_Petróleo_%                                              NaN
# Preco_Fechamento_Petróleo_%                                         NaN
# Preco_Corrigido_Petróleo_%                                          NaN
# Preco_Abertura_Real_%                                               NaN
# Preco_Alta_Real_%                                                   NaN
# Preco_Baixo_Real_%                                                  NaN
# Preco_Fechamento_Real_%                                             NaN
# Preco_Corrigido_Real_%                                              NaN
# Correlacao_Preco_Abertura_PetrobrasPreco_Alta_P...                  NaN
# Correlacao_Preco_Abertura_PetrobrasPreco_Baixo_...                  NaN
# Correlacao_Preco_Abertura_PetrobrasPreco_Fecham...                  NaN
# Correlacao_Preco_Abertura_PetrobrasPreco_Abertu...                  NaN
# Correlacao_Preco_Abertura_PetrobrasPreco_Alta_P...                  NaN
# Correlacao_Preco_Abertura_PetrobrasPreco_Baixo_...                  NaN
# Correlacao_Preco_Abertura_PetrobrasPreco_Fecham...                  NaN
# Correlacao_Preco_Abertura_PetrobrasPreco_Corrig...                  NaN
# Correlacao_Preco_Abertura_PetrobrasPreco_Abertu...                  NaN
# Correlacao_Preco_Abertura_PetrobrasPreco_Alta_Real                  NaN
# Correlacao_Preco_Abertura_PetrobrasPreco_Baixo_...                  NaN
# Correlacao_Preco_Abertura_PetrobrasPreco_Fecham...                  NaN
# Correlacao_Preco_Abertura_PetrobrasPreco_Corrig...                  NaN
# Correlacao_Preco_Alta_PetrobrasPreco_Baixo_Petr...                  NaN
# Correlacao_Preco_Alta_PetrobrasPreco_Fechamento...                  NaN
# Correlacao_Preco_Alta_PetrobrasPreco_Abertura_P...                  NaN
# Correlacao_Preco_Alta_PetrobrasPreco_Alta_Petróleo                  NaN
# Correlacao_Preco_Alta_PetrobrasPreco_Baixo_Petr...                  NaN
# Correlacao_Preco_Alta_PetrobrasPreco_Fechamento...                  NaN
# Correlacao_Preco_Alta_PetrobrasPreco_Corrigido_...                  NaN
# Correlacao_Preco_Alta_PetrobrasPreco_Abertura_Real                  NaN
# Correlacao_Preco_Alta_PetrobrasPreco_Alta_Real                      NaN
# Correlacao_Preco_Alta_PetrobrasPreco_Baixo_Real                     NaN
# Correlacao_Preco_Alta_PetrobrasPreco_Fechamento...                  NaN
# Correlacao_Preco_Alta_PetrobrasPreco_Corrigido_...                  NaN
# Correlacao_Preco_Baixo_PetrobrasPreco_Fechament...                  NaN
# Correlacao_Preco_Baixo_PetrobrasPreco_Abertura_...                  NaN
# Correlacao_Preco_Baixo_PetrobrasPreco_Alta_Petr...                  NaN
# Correlacao_Preco_Baixo_PetrobrasPreco_Baixo_Pet...                  NaN
# Correlacao_Preco_Baixo_PetrobrasPreco_Fechament...                  NaN
# Correlacao_Preco_Baixo_PetrobrasPreco_Corrigido...                  NaN
# Correlacao_Preco_Baixo_PetrobrasPreco_Abertura_...                  NaN
# Correlacao_Preco_Baixo_PetrobrasPreco_Alta_Real                     NaN
# Correlacao_Preco_Baixo_PetrobrasPreco_Baixo_Real                    NaN
# Correlacao_Preco_Baixo_PetrobrasPreco_Fechament...                  NaN
# Correlacao_Preco_Baixo_PetrobrasPreco_Corrigido...                  NaN
# Correlacao_Preco_Fechamento_PetrobrasPreco_Aber...                  NaN
# Correlacao_Preco_Fechamento_PetrobrasPreco_Alta...                  NaN
# Correlacao_Preco_Fechamento_PetrobrasPreco_Baix...                  NaN
# Correlacao_Preco_Fechamento_PetrobrasPreco_Fech...                  NaN
# Correlacao_Preco_Fechamento_PetrobrasPreco_Corr...                  NaN
# Correlacao_Preco_Fechamento_PetrobrasPreco_Aber...                  NaN
# Correlacao_Preco_Fechamento_PetrobrasPreco_Alta...                  NaN
# Correlacao_Preco_Fechamento_PetrobrasPreco_Baix...                  NaN
# Correlacao_Preco_Fechamento_PetrobrasPreco_Fech...                  NaN
# Correlacao_Preco_Fechamento_PetrobrasPreco_Corr...                  NaN
# Correlacao_Preco_Abertura_PetróleoPreco_Alta_Pe...                  NaN
# Correlacao_Preco_Abertura_PetróleoPreco_Baixo_P...                  NaN
# Correlacao_Preco_Abertura_PetróleoPreco_Fechame...                  NaN
# Correlacao_Preco_Abertura_PetróleoPreco_Corrigi...                  NaN
# Correlacao_Preco_Abertura_PetróleoPreco_Abertur...                  NaN
# Correlacao_Preco_Abertura_PetróleoPreco_Alta_Real                   NaN
# Correlacao_Preco_Abertura_PetróleoPreco_Baixo_Real                  NaN
# Correlacao_Preco_Abertura_PetróleoPreco_Fechame...                  NaN
# Correlacao_Preco_Abertura_PetróleoPreco_Corrigi...                  NaN
# Correlacao_Preco_Alta_PetróleoPreco_Baixo_Petróleo                  NaN
# Correlacao_Preco_Alta_PetróleoPreco_Fechamento_...                  NaN
# Correlacao_Preco_Alta_PetróleoPreco_Corrigido_P...                  NaN
# Correlacao_Preco_Alta_PetróleoPreco_Abertura_Real                   NaN
# Correlacao_Preco_Alta_PetróleoPreco_Alta_Real                       NaN
# Correlacao_Preco_Alta_PetróleoPreco_Baixo_Real                      NaN
# Correlacao_Preco_Alta_PetróleoPreco_Fechamento_...                  NaN
# Correlacao_Preco_Alta_PetróleoPreco_Corrigido_Real                  NaN
# Correlacao_Preco_Baixo_PetróleoPreco_Fechamento...                  NaN
# Correlacao_Preco_Baixo_PetróleoPreco_Corrigido_...                  NaN
# Correlacao_Preco_Baixo_PetróleoPreco_Abertura_Real                  NaN
# Correlacao_Preco_Baixo_PetróleoPreco_Alta_Real                      NaN
# Correlacao_Preco_Baixo_PetróleoPreco_Baixo_Real                     NaN
# Correlacao_Preco_Baixo_PetróleoPreco_Fechamento...                  NaN
# Correlacao_Preco_Baixo_PetróleoPreco_Corrigido_...                  NaN
# Correlacao_Preco_Fechamento_PetróleoPreco_Corri...                  NaN
# Correlacao_Preco_Fechamento_PetróleoPreco_Abert...                  NaN
# Correlacao_Preco_Fechamento_PetróleoPreco_Alta_...                  NaN
# Correlacao_Preco_Fechamento_PetróleoPreco_Baixo...                  NaN
# Correlacao_Preco_Fechamento_PetróleoPreco_Fecha...                  NaN
# Correlacao_Preco_Fechamento_PetróleoPreco_Corri...                  NaN
# Correlacao_Preco_Corrigido_PetróleoPreco_Abertu...                  NaN
# Correlacao_Preco_Corrigido_PetróleoPreco_Alta_Real                  NaN
# Correlacao_Preco_Corrigido_PetróleoPreco_Baixo_...                  NaN
# Correlacao_Preco_Corrigido_PetróleoPreco_Fecham...                  NaN
# Correlacao_Preco_Corrigido_PetróleoPreco_Corrig...                  NaN
# Correlacao_Preco_Abertura_RealPreco_Alta_Real                       NaN
# Correlacao_Preco_Abertura_RealPreco_Baixo_Real                      NaN
# Correlacao_Preco_Abertura_RealPreco_Fechamento_...                  NaN
# Correlacao_Preco_Abertura_RealPreco_Corrigido_Real                  NaN
# Correlacao_Preco_Alta_RealPreco_Baixo_Real                          NaN
# Correlacao_Preco_Alta_RealPreco_Fechamento_Real                     NaN
# Correlacao_Preco_Alta_RealPreco_Corrigido_Real                      NaN
# Correlacao_Preco_Baixo_RealPreco_Fechamento_Real                    NaN
# Correlacao_Preco_Baixo_RealPreco_Corrigido_Real                     NaN
# Correlacao_Preco_Fechamento_RealPreco_Corrigido...                  NaN

# %%
## Lembrar de remover colunas com alta correlação
# Matriz de Correlação
corr_matrix = pb_petro_real.corr().abs()
corr_matrix
# Out:
#                                                     Preco_Abertura_Petrobras  \
# Preco_Abertura_Petrobras                                            1.000000
# Preco_Alta_Petrobras                                                0.999363
# Preco_Baixo_Petrobras                                               0.998994
# Preco_Fechamento_Petrobras                                          0.998407
# Preco_Abertura_Petróleo                                             0.586942
# Preco_Alta_Petróleo                                                 0.591968
# Preco_Baixo_Petróleo                                                0.568908
# Preco_Fechamento_Petróleo                                           0.582803
# Preco_Corrigido_Petróleo                                            0.582803
# Preco_Abertura_Real                                                 0.315660
# Preco_Alta_Real                                                     0.322618
# Correlacao_Preco_Fechamento_RealPreco_Corrigido...                       NaN
#
#                                                     Preco_Alta_Petrobras  \
# Preco_Abertura_Petrobras                                        0.999363
# Preco_Alta_Petrobras                                            1.000000
# Preco_Baixo_Petrobras                                           0.998735
# Preco_Fechamento_Petrobras                                      0.999107
# Preco_Abertura_Petróleo                                         0.584659
# Preco_Alta_Petróleo                                             0.590268
# Preco_Baixo_Petróleo                                            0.566425
# Preco_Fechamento_Petróleo                                       0.581009
# Preco_Corrigido_Petróleo                                        0.581009
# Preco_Abertura_Real                                             0.321645
# Preco_Alta_Real                                                 0.328531
# Preco_Baixo_Real                                                0.309335
# Preco_Fechamento_Real                                           0.321080
# Preco_Corrigido_Real                                            0.321080
# Preco_Abertura_Petrobras_Media                                  0.978492
# Preco_Alta_Petrobras_Media                                      0.978626
# Preco_Baixo_Petrobras_Media                                     0.979324
# Preco_Fechamento_Petrobras_Media                                0.979707
# Preco_Abertura_Petróleo_Media                                   0.620361
# Preco_Alta_Petróleo_Media                                       0.624172
# Preco_Baixo_Petróleo_Media                                      0.601460
# Preco_Fechamento_Petróleo_Media                                 0.616549
# Preco_Corrigido_Petróleo_Media                                  0.616549
# Preco_Abertura_Real_Media                                       0.258446
# Preco_Alta_Real_Media                                           0.267783
# Preco_Baixo_Real_Media                                          0.243281
# Preco_Fechamento_Real_Media                                     0.257634
# Preco_Corrigido_Real_Media                                      0.257634
# Preco_Abertura_Petrobras_%                                      0.108435
# Preco_Alta_Petrobras_%                                          0.113236
# Preco_Baixo_Petrobras_%                                         0.102791
# Preco_Fechamento_Petrobras_%                                    0.104611
# Preco_Abertura_Petróleo_%                                       0.029711
# Preco_Alta_Petróleo_%                                           0.029336
# Preco_Baixo_Petróleo_%                                          0.028247
# Preco_Fechamento_Petróleo_%                                     0.025682
# Preco_Corrigido_Petróleo_%                                      0.025682
# Preco_Abertura_Real_%                                           0.025484
# Preco_Alta_Real_%                                               0.026781
# Preco_Baixo_Real_%                                              0.020103
# Preco_Fechamento_Real_%                                         0.025455
# Preco_Corrigido_Real_%                                          0.025455
# Correlacao_Preco_Abertura_PetrobrasPreco_Alta_P...              0.101591
# Correlacao_Preco_Abertura_PetrobrasPreco_Baixo_...              0.158881
# Correlacao_Preco_Abertura_PetrobrasPreco_Fecham...              0.137597
# Correlacao_Preco_Abertura_PetrobrasPreco_Abertu...              0.223903
# Correlacao_Preco_Abertura_PetrobrasPreco_Alta_P...              0.229529
# Correlacao_Preco_Abertura_PetrobrasPreco_Baixo_...              0.216994
# Correlacao_Preco_Abertura_PetrobrasPreco_Fecham...              0.206332
# Correlacao_Preco_Abertura_PetrobrasPreco_Corrig...              0.206332
# Correlacao_Preco_Abertura_PetrobrasPreco_Abertu...              0.174757
# Correlacao_Preco_Abertura_PetrobrasPreco_Alta_Real              0.161235
# Correlacao_Preco_Abertura_PetrobrasPreco_Baixo_...              0.182884
# Correlacao_Preco_Abertura_PetrobrasPreco_Fecham...              0.176221
# Correlacao_Preco_Abertura_PetrobrasPreco_Corrig...              0.176221
# Correlacao_Preco_Alta_PetrobrasPreco_Baixo_Petr...              0.158380
# Correlacao_Preco_Alta_PetrobrasPreco_Fechamento...              0.114753
# Correlacao_Preco_Alta_PetrobrasPreco_Abertura_P...              0.230715
# Correlacao_Preco_Alta_PetrobrasPreco_Alta_Petróleo              0.259244
# Correlacao_Preco_Alta_PetrobrasPreco_Baixo_Petr...              0.222440
# Correlacao_Preco_Alta_PetrobrasPreco_Fechamento...              0.243733
# Correlacao_Preco_Alta_PetrobrasPreco_Corrigido_...              0.243733
# Correlacao_Preco_Alta_PetrobrasPreco_Abertura_Real              0.157267
# Correlacao_Preco_Alta_PetrobrasPreco_Alta_Real                  0.147862
# Correlacao_Preco_Alta_PetrobrasPreco_Baixo_Real                 0.161919
# Correlacao_Preco_Alta_PetrobrasPreco_Fechamento...              0.159553
# Correlacao_Preco_Alta_PetrobrasPreco_Corrigido_...              0.159553
# Correlacao_Preco_Baixo_PetrobrasPreco_Fechament...              0.156503
# Correlacao_Preco_Baixo_PetrobrasPreco_Abertura_...              0.215043
# Correlacao_Preco_Baixo_PetrobrasPreco_Alta_Petr...              0.236771
# Correlacao_Preco_Baixo_PetrobrasPreco_Baixo_Pet...              0.223310
# Correlacao_Preco_Baixo_PetrobrasPreco_Fechament...              0.224486
# Correlacao_Preco_Baixo_PetrobrasPreco_Corrigido...              0.224486
# Correlacao_Preco_Baixo_PetrobrasPreco_Abertura_...              0.187238
# Correlacao_Preco_Baixo_PetrobrasPreco_Alta_Real                 0.184225
# Correlacao_Preco_Baixo_PetrobrasPreco_Baixo_Real                0.200512
# Correlacao_Preco_Baixo_PetrobrasPreco_Fechament...              0.188760
# Correlacao_Preco_Baixo_PetrobrasPreco_Corrigido...              0.188760
# Correlacao_Preco_Fechamento_PetrobrasPreco_Aber...              0.206172
# Correlacao_Preco_Fechamento_PetrobrasPreco_Alta...              0.256708
# Correlacao_Preco_Fechamento_PetrobrasPreco_Baix...              0.227175
# Correlacao_Preco_Fechamento_PetrobrasPreco_Fech...              0.266712
# Correlacao_Preco_Fechamento_PetrobrasPreco_Corr...              0.266712
# Correlacao_Preco_Fechamento_PetrobrasPreco_Aber...              0.182088
# Correlacao_Preco_Fechamento_PetrobrasPreco_Alta...              0.170155
# Correlacao_Preco_Fechamento_PetrobrasPreco_Baix...              0.182969
# Correlacao_Preco_Fechamento_PetrobrasPreco_Fech...              0.184087
# Correlacao_Preco_Fechamento_PetrobrasPreco_Corr...              0.184087
# Correlacao_Preco_Abertura_PetróleoPreco_Alta_Pe...              0.274971
# Correlacao_Preco_Abertura_PetróleoPreco_Baixo_P...              0.075124
# Correlacao_Preco_Abertura_PetróleoPreco_Fechame...              0.205746
# Correlacao_Preco_Abertura_PetróleoPreco_Corrigi...              0.205746
# Correlacao_Preco_Abertura_PetróleoPreco_Abertur...              0.295239
# Correlacao_Preco_Abertura_PetróleoPreco_Alta_Real               0.286777
# Correlacao_Preco_Abertura_PetróleoPreco_Baixo_Real              0.283765
# Correlacao_Preco_Abertura_PetróleoPreco_Fechame...              0.295887
# Correlacao_Preco_Abertura_PetróleoPreco_Corrigi...              0.295887
# Correlacao_Preco_Alta_PetróleoPreco_Baixo_Petróleo              0.044355
# Correlacao_Preco_Alta_PetróleoPreco_Fechamento_...              0.034365
# Correlacao_Preco_Alta_PetróleoPreco_Corrigido_P...              0.034365
# Correlacao_Preco_Alta_PetróleoPreco_Abertura_Real               0.315519
# Correlacao_Preco_Alta_PetróleoPreco_Alta_Real                   0.304004
# Correlacao_Preco_Alta_PetróleoPreco_Baixo_Real                  0.294638
# Correlacao_Preco_Alta_PetróleoPreco_Fechamento_...              0.314998
# Correlacao_Preco_Alta_PetróleoPreco_Corrigido_Real              0.314998
# Correlacao_Preco_Baixo_PetróleoPreco_Fechamento...              0.330277
# Correlacao_Preco_Baixo_PetróleoPreco_Corrigido_...              0.330277
# Correlacao_Preco_Baixo_PetróleoPreco_Abertura_Real              0.296928
# Correlacao_Preco_Baixo_PetróleoPreco_Alta_Real                  0.281364
# Correlacao_Preco_Baixo_PetróleoPreco_Baixo_Real                 0.272247
# Correlacao_Preco_Baixo_PetróleoPreco_Fechamento...              0.296764
# Correlacao_Preco_Baixo_PetróleoPreco_Corrigido_...              0.296764
# Correlacao_Preco_Fechamento_PetróleoPreco_Corri...                   NaN
# Correlacao_Preco_Fechamento_PetróleoPreco_Abert...              0.323475
# Correlacao_Preco_Fechamento_PetróleoPreco_Alta_...              0.303339
# Correlacao_Preco_Fechamento_PetróleoPreco_Baixo...              0.292897
# Correlacao_Preco_Fechamento_PetróleoPreco_Fecha...              0.323212
# Correlacao_Preco_Fechamento_PetróleoPreco_Corri...              0.323212
# Correlacao_Preco_Corrigido_PetróleoPreco_Abertu...              0.323475
# Correlacao_Preco_Corrigido_PetróleoPreco_Alta_Real              0.303339
# Correlacao_Preco_Corrigido_PetróleoPreco_Baixo_
# Correlacao_Preco_Abertura_PetróleoPreco_Fechame...               0.300585
# Correlacao_Preco_Abertura_PetróleoPreco_Corrigi...               0.300585
# Correlacao_Preco_Alta_PetróleoPreco_Baixo_Petróleo               0.048963
# Correlacao_Preco_Alta_PetróleoPreco_Fechamento_...               0.034391
# Correlacao_Preco_Alta_PetróleoPreco_Corrigido_P...               0.034391
# Correlacao_Preco_Alta_PetróleoPreco_Abertura_Real                0.320159
# Correlacao_Preco_Alta_PetróleoPreco_Alta_Real                    0.308970
# Correlacao_Preco_Alta_PetróleoPreco_Baixo_Real                   0.298910
# Correlacao_Preco_Alta_PetróleoPreco_Fechamento_...               0.319666
# Correlacao_Preco_Alta_PetróleoPreco_Corrigido_Real               0.319666
# Correlacao_Preco_Baixo_PetróleoPreco_Fechamento...               0.332846
# Correlacao_Preco_Baixo_PetróleoPreco_Corrigido_...               0.332846
# Correlacao_Preco_Baixo_PetróleoPreco_Abertura_Real               0.300541
# Correlacao_Preco_Baixo_PetróleoPreco_Alta_Real                   0.285341
# Correlacao_Preco_Baixo_PetróleoPreco_Baixo_Real                  0.275446
# Correlacao_Preco_Baixo_PetróleoPreco_Fechamento...               0.300421
# Correlacao_Preco_Baixo_PetróleoPreco_Corrigido_...               0.300421
# Correlacao_Preco_Fechamento_PetróleoPreco_Corri...                    NaN
# Correlacao_Preco_Fechamento_PetróleoPreco_Abert...               0.327595
# Correlacao_Preco_Fechamento_PetróleoPreco_Alta_...               0.307846
# Correlacao_Preco_Fechamento_PetróleoPreco_Baixo...               0.296685
# Correlacao_Preco_Fechamento_PetróleoPreco_Fecha...               0.327309
# Correlacao_Preco_Fechamento_PetróleoPreco_Corri...               0.327309
# Correlacao_Preco_Corrigido_PetróleoPreco_Abertu...               0.327595
# Correlacao_Preco_Corrigido_PetróleoPreco_Alta_Real               0.307846
# Correlacao_Preco_Corrigido_PetróleoPreco_Baixo_...               0.296685
# Correlacao_Preco_Corrigido_PetróleoPreco_Fecham...               0.327309
# Correlacao_Preco_Corrigido_PetróleoPreco_Corrig...               0.327309
# Correlacao_Preco_Abertura_RealPreco_Alta_Real                    0.034949
# Correlacao_Preco_Abertura_RealPreco_Baixo_Real                   0.191592
# Correlacao_Preco_Abertura_RealPreco_Fechamento_...               0.035352
# Correlacao_Preco_Abertura_RealPreco_Corrigido_Real               0.035352
# Correlacao_Preco_Alta_RealPreco_Baixo_Real                       0.219289
# Correlacao_Preco_Alta_RealPreco_Fechamento_Real                  0.036874
# Correlacao_Preco_Alta_RealPreco_Corrigido_Real                   0.036874
# Correlacao_Preco_Baixo_RealPreco_Fechamento_Real                 0.185288
# Correlacao_Preco_Baixo_RealPreco_Corrigido_Real                  0.185288
# Correlacao_Preco_Fechamento_RealPreco_Corrigido...                    NaN
#
#                                                     Preco_Fechamento_Petrobras  \
# Preco_Abertura_Petrobras                                              0.998407
# Preco_Alta_Petrobras                                                  0.999107
# Preco_Baixo_Petrobras                                                 0.999276
# Preco_Fechamento_Petrobras                                            1.000000
# Preco_Abertura_Petróleo                                               0.586594
# Preco_Alta_Petróleo                                                   0.592144
# Preco_Baixo_Petróleo                                                  0.569105
# Preco_Fechamento_Petróleo                                             0.583514
# Preco_Corrigido_Petróleo                                              0.583514
# Preco_Abertura_Real                                                   0.313876
# Preco_Alta_Real                                                       0.321291
# Preco_Baixo_Real                                                      0.301562
# Preco_Fechamento_Real                                                 0.313249
# Preco_Corrigido_Real                                                  0.313249
# Preco_Abertura_Petrobras_Media                                        0.977208
# Preco_Alta_Petrobras_Media                                            0.977219
# Preco_Baixo_Petrobras_Media                                           0.978205
# Preco_Fechamento_Petrobras_Media                                      0.978481
# Preco_Abertura_Petróleo_Media                                         0.621951
# Preco_Alta_Petróleo_Media                                             0.625593
# Preco_Baixo_Petróleo_Media                                            0.603303
# Preco_Fechamento_Petróleo_Media                                       0.618127
# Preco_Corrigido_Petróleo_Media                                        0.618127
# Preco_Abertura_Real_Media                                             0.253218
# Preco_Alta_Real_Media                                                 0.262620
# Preco_Baixo_Real_Media                                                0.237954
# Preco_Fechamento_Real_Media                                           0.252387
# Preco_Corrigido_Real_Media                                            0.252387
# Preco_Abertura_Petrobras_%                                            0.112336
# Preco_Alta_Petrobras_%                                                0.117341
# Preco_Baixo_Petrobras_%                                               0.109258
# Preco_Fechamento_Petrobras_%                                          0.111988
# Preco_Abertura_Petróleo_%                                             0.036613
# Preco_Alta_Petróleo_%                                                 0.036357
# Preco_Baixo_Petróleo_%                                                0.035556
# Preco_Fechamento_Petróleo_%                                           0.033445
# Preco_Corrigido_Petróleo_%                                            0.033445
# Preco_Abertura_Real_%                                                 0.016455
# Preco_Alta_Real_%                                                     0.018785
# Preco_Baixo_Real_%                                                    0.011147
# Preco_Fechamento_Real_%                                               0.016269
# Preco_Corrigido_Real_%                                                0.016269
# Correlacao_Preco_Abertura_PetrobrasPreco_Alta_P...                    0.107770
# Correlacao_Preco_Abertura_PetrobrasPreco_Baixo_...                    0.160575
# Correlacao_Preco_Abertura_PetrobrasPreco_Fecham...                    0.142057
# Correlacao_Preco_Abertura_PetrobrasPreco_Abertu...                    0.223503
# Correlacao_Preco_Abertura_PetrobrasPreco_Alta_P...                    0.229497
# Correlacao_Preco_Abertura_PetrobrasPreco_Baixo_...                    0.216661
# Correlacao_Preco_Abertura_PetrobrasPreco_Fecham...                    0.206125
# Correlacao_Preco_Abertura_PetrobrasPreco_Corrig...                    0.206125
# Correlacao_Preco_Abertura_PetrobrasPreco_Abertu...                    0.176297
# Correlacao_Preco_Abertura_PetrobrasPreco_Alta_Real                    0.162837
# Correlacao_Preco_Abertura_PetrobrasPreco_Baixo_...                    0.184334
# Correlacao_Preco_Abertura_PetrobrasPreco_Fecham...                    0.177788
# Correlacao_Preco_Abertura_PetrobrasPreco_Corrig...                    0.177788
# Correlacao_Preco_Alta_PetrobrasPreco_Baixo_Petr...                    0.161744
# Correlacao_Preco_Alta_PetrobrasPreco_Fechamento...                    0.118319
# Correlacao_Preco_Alta_PetrobrasPreco_Abertura_P...                    0.230527
# Correlacao_Preco_Alta_PetrobrasPreco_Alta_Petróleo                    0.259186
# Correlacao_Preco_Alta_PetrobrasPreco_Baixo_Petr...                    0.221998
# Correlacao_Preco_Alta_PetrobrasPreco_Fechamento...                    0.243112
# Correlacao_Preco_Alta_PetrobrasPreco_Corrigido_...                    0.243112
# Correlacao_Preco_Alta_PetrobrasPreco_Abertura_Real                    0.158719
# Correlacao_Preco_Alta_PetrobrasPreco_Alta_Real                        0.149456
# Correlacao_Preco_Alta_PetrobrasPreco_Baixo_Real                       0.163544
# Correlacao_Preco_Alta_PetrobrasPreco_Fechamento...                    0.161042
# Correlacao_Preco_Alta_PetrobrasPreco_Corrigido_...                    0.161042
# Correlacao_Preco_Baixo_PetrobrasPreco_Fechament...                    0.161880
# Correlacao_Preco_Baixo_PetrobrasPreco_Abertura_...                    0.214603
# Correlacao_Preco_Baixo_PetrobrasPreco_Alta_Petr...                    0.236441
# Correlacao_Preco_Baixo_PetrobrasPreco_Baixo_Pet...                    0.222820
# Correlacao_Preco_Baixo_PetrobrasPreco_Fechament...                    0.223760
# Correlacao_Preco_Baixo_PetrobrasPreco_Corrigido...                    0.223760
# Correlacao_Preco_Baixo_PetrobrasPreco_Abertura_...                    0.189178
# Correlacao_Preco_Baixo_PetrobrasPreco_Alta_Real                       0.186228
# Correlacao_Preco_Baixo_PetrobrasPreco_Baixo_Real                      0.202534
# Correlacao_Preco_Baixo_PetrobrasPreco_Fechament...                    0.190721
# Correlacao_Preco_Baixo_PetrobrasPreco_Corrigido...                    0.190721
# Correlacao_Preco_Fechamento_PetrobrasPreco_Aber...                    0.206015
# Correlacao_Preco_Fechamento_PetrobrasPreco_Alta...                    0.256546
# Correlacao_Preco_Fechamento_PetrobrasPreco_Baix...                    0.226882
# Correlacao_Preco_Fechamento_PetrobrasPreco_Fech...                    0.265866
# Correlacao_Preco_Fechamento_PetrobrasPreco_Corr...                    0.265866
# Correlacao_Preco_Fechamento_PetrobrasPreco_Aber...                    0.183996
# Correlacao_Preco_Fechamento_PetrobrasPreco_Alta...                    0.172365
# Correlacao_Preco_Fechamento_PetrobrasPreco_Baix...                    0.185180
# Correlacao_Preco_Fechamento_PetrobrasPreco_Fech...                    0.186039
# Correlacao_Preco_Fechamento_PetrobrasPreco_Corr...                    0.186039
# Correlacao_Preco_Abertura_PetróleoPreco_Alta_Pe...                    0.272023
# Correlacao_Preco_Abertura_PetróleoPreco_Baixo_P...                    0.073656
# Correlacao_Preco_Abertura_PetróleoPreco_Fechame...                    0.203230
# Correlacao_Preco_Abertura_PetróleoPreco_Corrigi...                    0.203230
# Correlacao_Preco_Abertura_PetróleoPreco_Abertur...                    0.296171
# Correlacao_Preco_Abertura_PetróleoPreco_Alta_Real                     0.287753
# Correlacao_Preco_Abertura_PetróleoPreco_Baixo_Real                    0.284460
# Correlacao_Preco_Abertura_PetróleoPreco_Fechame...                    0.296801
# Correlacao_Preco_Abertura_PetróleoPreco_Corrigi...                    0.296801
# Correlacao_Preco_Alta_PetróleoPreco_Baixo_Petróleo                    0.045960
# Correlacao_Preco_Alta_PetróleoPreco_Fechamento_...                    0.033117
# Correlacao_Preco_Alta_PetróleoPreco_Corrigido_P...                    0.033117
# Correlacao_Preco_Alta_PetróleoPreco_Abertura_Real                     0.316402
# Correlacao_Preco_Alta_PetróleoPreco_Alta_Real                         0.304946
# Correlacao_Preco_Alta_PetróleoPreco_Baixo_Real                        0.295395
# Correlacao_Preco_Alta_PetróleoPreco_Fechamento_...                    0.315880
# Correlacao_Preco_Alta_PetróleoPreco_Corrigido_Real                    0.315880
# Correlacao_Preco_Baixo_PetróleoPreco_Fechamento...                    0.330346
# Correlacao_Preco_Baixo_PetróleoPreco_Corrigido_...                    0.330346
# Correlacao_Preco_Baixo_PetróleoPreco_Abertura_Real                    0.297634
# Correlacao_Preco_Baixo_PetróleoPreco_Alta_Real                        0.282113
# Correlacao_Preco_Baixo_PetróleoPreco_Baixo_Real                       0.272777
# Correlacao_Preco_Baixo_PetróleoPreco_Fechamento...                    0.297465
# Correlacao_Preco_Baixo_PetróleoPreco_Corrigido_...                    0.297465
# Correlacao_Preco_Fechamento_PetróleoPreco_Corri...                         NaN
# Correlacao_Preco_Fechamento_PetróleoPreco_Abert...                    0.324190
# Correlacao_Preco_Fechamento_PetróleoPreco_Alta_...                    0.304117
# Correlacao_Preco_Fechamento_PetróleoPreco_Baixo...                    0.293559
# Correlacao_Preco_Fechamento_PetróleoPreco_Fecha...                    0.323917
# Correlacao_Preco_Fechamento_PetróleoPreco_Corri...                    0.323917
# Correlacao_Preco_Corrigido_PetróleoPreco_Abertu...                    0.324190
# Correlacao_Preco_Corrigido_PetróleoPreco_Alta_Real                    0.304117
# Correlacao_Preco_Corrigido_PetróleoPreco_Baixo_...                    0.293559
# Correlacao_Preco_Corrigido_PetróleoPreco_Fecham...                    0.323917
# Correlacao_Preco_Corrigido_PetróleoPreco_Corrig...                    0.323917
# Correlacao_Preco_Abertura_RealPreco_Alta_Real                         0.037937
# Correlacao_Preco_Abertura_RealPreco_Baixo_Real                        0.194847
# Correlacao_Preco_Abertura_RealPreco_Fechamento_...                    0.028542
# Correlacao_Preco_Abertura_RealPreco_Corrigido_Real                    0.028542
# Correlacao_Preco_Alta_RealPreco_Baixo_Real                            0.221441
# Correlacao_Preco_Alta_RealPreco_Fechamento_Real                       0.039951
# Correlacao_Preco_Alta_RealPreco_Corrigido_Real                        0.039951
# Correlacao_Preco_Baixo_RealPreco_Fechamento_Real                      0.189221
# Correlacao_Preco_Baixo_RealPreco_Corrigido_Real                       0.189221
# Correlacao_Preco_Fechamento_RealPreco_Corrigido...                         NaN
#
#                                                     Preco_Abertura_Petróleo  \
# Preco_Abertura_Petrobras                                           0.586942
# Preco_Alta_Petrobras                                               0.584659
# Preco_Baixo_Petrobras                                              0.589234
# Preco_Fechamento_Petrobras                                         0.586594
# Preco_Abertura_Petróleo                                            1.000000
# Preco_Alta_Petróleo                                                0.997860
# Preco_Baixo_Petróleo                                               0.988309
# Preco_Fechamento_Petróleo                                          0.994179
# Preco_Corrigido_Petróleo                                           0.994179
# Preco_Abertura_Real                                                0.200439
# Preco_Alta_Real                                                    0.199399
# Preco_Baixo_Real                                                   0.209082
# Preco_Fechamento_Real                                              0.201685
# Preco_Corrigido_Real                                               0.201685
# Preco_Abertura_Petrobras_Media                                     0.587440
# Preco_Alta_Petrobras_Media                                         0.586180
# Preco_Baixo_Petrobras_Media                                        0.589276
# Preco_Fechamento_Petrobras_Media                                   0.587722
# Preco_Abertura_Petróleo_Media                                      0.953833
# Preco_Alta_Petróleo_Media                                          0.953256
# Preco_Baixo_Petróleo_Media                                         0.958046
# Preco_Fechamento_Petróleo_Media                                    0.956504
# Preco_Corrigido_Petróleo_Media                                     0.956504
# Preco_Abertura_Real_Media                                          0.313489
# Preco_Alta_Real_Media                                              0.310541
# Preco_Baixo_Real_Media                                             0.323879
# Preco_Fechamento_Real_Media                                        0.316008
# Preco_Corrigido_Real_Media                                         0.316008
# Preco_Abertura_Petrobras_%                                         0.166583
# Preco_Alta_Petrobras_%                                             0.175590
# Preco_Baixo_Petrobras_%                                            0.153886
# Preco_Fechamento_Petrobras_%                                       0.161867
# Preco_Abertura_Petróleo_%                                          0.448660
# Preco_Alta_Petróleo_%                                              0.449461
# Preco_Baixo_Petróleo_%                                             0.426904
# Preco_Fechamento_Petróleo_%                                        0.437464
# Preco_Corrigido_Petróleo_%                                         0.437464
# Preco_Abertura_Real_%                                              0.152794
# Preco_Alta_Real_%                                                  0.152289
# Preco_Baixo_Real_%                                                 0.149978
# Preco_Fechamento_Real_%                                            0.151408
# Preco_Corrigido_Real_%                                             0.151408
# Correlacao_Preco_Abertura_PetrobrasPreco_Alta_P...                 0.000769
# Correlacao_Preco_Abertura_PetrobrasPreco_Baixo_...                 0.119594
# Correlacao_Preco_Abertura_PetrobrasPreco_Fecham...                 0.100272
# Correlacao_Preco_Abertura_PetrobrasPreco_Abertu...                 0.081535
# Correlacao_Preco_Abertura_PetrobrasPreco_Alta_P...                 0.115567
# Correlacao_Preco_Abertura_PetrobrasPreco_Baixo_...                 0.132273
# Correlacao_Preco_Abertura_PetrobrasPreco_Fecham...                 0.123451
# Correlacao_Preco_Abertura_PetrobrasPreco_Corrig...                 0.123451
# Correlacao_Preco_Abertura_PetrobrasPreco_Abertu...                 0.120798
# Correlacao_Preco_Abertura_PetrobrasPreco_Alta_Real                 0.101603
# Correlacao_Preco_Abertura_PetrobrasPreco_Baixo_...                 0.137878
# Correlacao_Preco_Abertura_PetrobrasPreco_Fecham...                 0.133122
# Correlacao_Preco_Abertura_PetrobrasPreco_Corrig...                 0.133122
# Correlacao_Preco_Alta_PetrobrasPreco_Baixo_Petr...                 0.080547
# Correlacao_Preco_Alta_PetrobrasPreco_Fechamento...                 0.107293
# Correlacao_Preco_Alta_PetrobrasPreco_Abertura_P...                 0.076048
# Correlacao_Preco_Alta_PetrobrasPreco_Alta_Petróleo                 0.111699
# Correlacao_Preco_Alta_PetrobrasPreco_Baixo_Petr...                 0.112958
# Correlacao_Preco_Alta_PetrobrasPreco_Fechamento...                 0.101390
# Correlacao_Preco_Alta_PetrobrasPreco_Corrigido_...                 0.101390
# Correlacao_Preco_Alta_PetrobrasPreco_Abertura_Real                 0.099159
# Correlacao_Preco_Alta_PetrobrasPreco_Alta_Real                     0.090949
# Correlacao_Preco_Alta_PetrobrasPreco_Baixo_Real                    0.124838
# Correlacao_Preco_Alta_PetrobrasPreco_Fechamento...                 0.117149
# Correlacao_Preco_Alta_PetrobrasPreco_Corrigido_...                 0.117149
# Correlacao_Preco_Baixo_PetrobrasPreco_Fechament...                 0.045536
# Correlacao_Preco_Baixo_PetrobrasPreco_Abertura_...                 0.033141
# Correlacao_Preco_Baixo_PetrobrasPreco_Alta_Petr...                 0.061453
# Correlacao_Preco_Baixo_PetrobrasPreco_Baixo_Pet...                 0.094335
# Correlacao_Preco_Baixo_PetrobrasPreco_Fechament...                 0.068222
# ...
# Correlacao_Preco_Corrigido_PetróleoPreco_Abertu...                                         0.054390
# Correlacao_Preco_Corrigido_PetróleoPreco_Alta_Real                                         0.027230
# Correlacao_Preco_Corrigido_PetróleoPreco_Baixo_...                                         0.077530
# Correlacao_Preco_Corrigido_PetróleoPreco_Fecham...                                         0.054560
# Correlacao_Preco_Corrigido_PetróleoPreco_Corrig...                                         0.054560
# Correlacao_Preco_Abertura_RealPreco_Alta_Real                                              0.702962
# Correlacao_Preco_Abertura_RealPreco_Baixo_Real                                             0.995600
# Correlacao_Preco_Abertura_RealPreco_Fechamento_...                                         0.109485
# Correlacao_Preco_Abertura_RealPreco_Corrigido_Real                                         0.109485
# Correlacao_Preco_Alta_RealPreco_Baixo_Real                                                 0.818279
# Correlacao_Preco_Alta_RealPreco_Fechamento_Real                                            0.702965
# Correlacao_Preco_Alta_RealPreco_Corrigido_Real                                             0.702965
# Correlacao_Preco_Baixo_RealPreco_Fechamento_Real                                           1.000000
# Correlacao_Preco_Baixo_RealPreco_Corrigido_Real                                            1.000000
# Correlacao_Preco_Fechamento_RealPreco_Corrigido...                                              NaN
#
#                                                     Correlacao_Preco_Fechamento_RealPreco_Corrigido_Real
# Preco_Abertura_Petrobras                                                                          NaN
# Preco_Alta_Petrobras                                                                              NaN
# Preco_Baixo_Petrobras                                                                             NaN
# Preco_Fechamento_Petrobras                                                                        NaN
# Preco_Abertura_Petróleo                                                                           NaN
# Preco_Alta_Petróleo                                                                               NaN
# Preco_Baixo_Petróleo                                                                              NaN
# Preco_Fechamento_Petróleo                                                                         NaN
# Preco_Corrigido_Petróleo                                                                          NaN
# Preco_Abertura_Real                                                                               NaN
# Preco_Alta_Real                                                                                   NaN
# Preco_Baixo_Real                                                                                  NaN
# Preco_Fechamento_Real                                                                             NaN
# Preco_Corrigido_Real                                                                              NaN
# Preco_Abertura_Petrobras_Media                                                                    NaN
# Preco_Alta_Petrobras_Media                                                                        NaN
# Preco_Baixo_Petrobras_Media                                                                       NaN
# Preco_Fechamento_Petrobras_Media                                                                  NaN
# Preco_Abertura_Petróleo_Media                                                                     NaN
# Preco_Alta_Petróleo_Media                                                                         NaN
# Preco_Baixo_Petróleo_Media                                                                        NaN
# Preco_Fechamento_Petróleo_Media                                                                   NaN
# Preco_Corrigido_Petróleo_Media                                                                    NaN
# Preco_Abertura_Real_Media                                                                         NaN
# Preco_Alta_Real_Media                                                                             NaN
# Preco_Baixo_Real_Media                                                                            NaN
# Preco_Fechamento_Real_Media                                                                       NaN
# Preco_Corrigido_Real_Media                                                                        NaN
# Preco_Abertura_Petrobras_%                                                                        NaN
# Preco_Alta_Petrobras_%                                                                            NaN
# Preco_Baixo_Petrobras_%                                                                           NaN
# Preco_Fechamento_Petrobras_%                                                                      NaN
# Preco_Abertura_Petróleo_%                                                                         NaN
# Preco_Alta_Petróleo_%                                                                             NaN
# Preco_Baixo_Petróleo_%                                                                            NaN
# Preco_Fechamento_Petróleo_%                                                                       NaN
# Preco_Corrigido_Petróleo_%                                                                        NaN
# Preco_Abertura_Real_%                                                                             NaN
# Preco_Alta_Real_%                                                                                 NaN
# Preco_Baixo_Real_%                                                                                NaN
# Preco_Fechamento_Real_%                                                                           NaN
# Preco_Corrigido_Real_%                                                                            NaN
# Correlacao_Preco_Abertura_PetrobrasPreco_Alta_P...                                                NaN
# Correlacao_Preco_Abertura_PetrobrasPreco_Baixo_...                                                NaN
# Correlacao_Preco_Abertura_PetrobrasPreco_Fecham...                                                NaN
# Correlacao_Preco_Abertura_PetrobrasPreco_Abertu...                                                NaN
# Correlacao_Preco_Abertura_PetrobrasPreco_Alta_P...                                                NaN
# Correlacao_Preco_Abertura_PetrobrasPreco_Baixo_...                                                NaN
# Correlacao_Preco_Abertura_PetrobrasPreco_Fecham...                                                NaN
# Correlacao_Preco_Abertura_PetrobrasPreco_Corrig...                                                NaN
# Correlacao_Preco_Abertura_PetrobrasPreco_Abertu...                                                NaN
# Correlacao_Preco_Abertura_PetrobrasPreco_Alta_Real                                                NaN
# Correlacao_Preco_Abertura_PetrobrasPreco_Baixo_...                                                NaN
# Correlacao_Preco_Abertura_PetrobrasPreco_Fecham...                                                NaN
# Correlacao_Preco_Abertura_PetrobrasPreco_Corrig...                                                NaN
# Correlacao_Preco_Alta_PetrobrasPreco_Baixo_Petr...                                                NaN
# Correlacao_Preco_Alta_PetrobrasPreco_Fechamento...                                                NaN
# Correlacao_Preco_Alta_PetrobrasPreco_Abertura_P...                                                NaN
# Correlacao_Preco_Alta_PetrobrasPreco_Alta_Petróleo                                                NaN
# Correlacao_Preco_Alta_PetrobrasPreco_Baixo_Petr...                                                NaN
# Correlacao_Preco_Alta_PetrobrasPreco_Fechamento...                                                NaN
# Correlacao_Preco_Alta_PetrobrasPreco_Corrigido_...                                                NaN
# Correlacao_Preco_Alta_PetrobrasPreco_Abertura_Real                                                NaN
# Correlacao_Preco_Alta_PetrobrasPreco_Alta_Real                                                    NaN
# Correlacao_Preco_Alta_PetrobrasPreco_Baixo_Real                                                   NaN
# Correlacao_Preco_Alta_PetrobrasPreco_Fechamento...                                                NaN
# Correlacao_Preco_Alta_PetrobrasPreco_Corrigido_...                                                NaN
# Correlacao_Preco_Baixo_PetrobrasPreco_Fechament...                                                NaN
# Correlacao_Preco_Baixo_PetrobrasPreco_Abertura_...                                                NaN
# Correlacao_Preco_Baixo_PetrobrasPreco_Alta_Petr...                                                NaN
# Correlacao_Preco_Baixo_PetrobrasPreco_Baixo_Pet...                                                NaN
# Correlacao_Preco_Baixo_PetrobrasPreco_Fechament...                                                NaN
# Correlacao_Preco_Baixo_PetrobrasPreco_Corrigido...                                                NaN
# Correlacao_Preco_Baixo_PetrobrasPreco_Abertura_...                                                NaN
# Correlacao_Preco_Baixo_PetrobrasPreco_Alta_Real                                                   NaN
# Correlacao_Preco_Baixo_PetrobrasPreco_Baixo_Real                                                  NaN
# Correlacao_Preco_Baixo_PetrobrasPreco_Fechament...                                                NaN
# Correlacao_Preco_Baixo_PetrobrasPreco_Corrigido...                                                NaN
# Correlacao_Preco_Fechamento_PetrobrasPreco_Aber...                                                NaN
# Correlacao_Preco_Fechamento_PetrobrasPreco_Alta...                                                NaN
# Correlacao_Preco_Fechamento_PetrobrasPreco_Baix...                                                NaN
# Correlacao_Preco_Fechamento_PetrobrasPreco_Fech...                                                NaN
# Correlacao_Preco_Fechamento_PetrobrasPreco_Corr...                                                NaN
# Correlacao_Preco_Fechamento_PetrobrasPreco_Aber...                                                NaN
# Correlacao_Preco_Fechamento_PetrobrasPreco_Alta...                                                NaN
# Correlacao_Preco_Fechamento_PetrobrasPreco_Baix...                                                NaN
# Correlacao_Preco_Fechamento_PetrobrasPreco_Fech...                                                NaN
# Correlacao_Preco_Fechamento_PetrobrasPreco_Corr...                                                NaN
# Correlacao_Preco_Abertura_PetróleoPreco_Alta_Pe...                                                NaN
# Correlacao_Preco_Abertura_PetróleoPreco_Baixo_P...                                                NaN
# Correlacao_Preco_Abertura_PetróleoPreco_Fechame...                                                NaN
# Correlacao_Preco_Abertura_PetróleoPreco_Corrigi...                                                NaN
# Correlacao_Preco_Abertura_PetróleoPreco_Abertur...                                                NaN
# Correlacao_Preco_Abertura_PetróleoPreco_Alta_Real                                                 NaN
# Correlacao_Preco_Abertura_PetróleoPreco_Baixo_Real                                                NaN
# Correlacao_Preco_Abertura_PetróleoPreco_Fechame...                                                NaN
# Correlacao_Preco_Abertura_PetróleoPreco_Corrigi...                                                NaN
# Correlacao_Preco_Alta_PetróleoPreco_Baixo_Petróleo                                                NaN
# Correlacao_Preco_Alta_PetróleoPreco_Fechamento_...                                                NaN
# Correlacao_Preco_Alta_PetróleoPreco_Corrigido_P...                                                NaN
# Correlacao_Preco_Alta_PetróleoPreco_Abertura_Real                                                 NaN
# Correlacao_Preco_Alta_PetróleoPreco_Alta_Real                                                     NaN
# Correlacao_Preco_Alta_PetróleoPreco_Baixo_Real                                                    NaN
# Correlacao_Preco_Alta_PetróleoPreco_Fechamento_...                                                NaN
# Correlacao_Preco_Alta_PetróleoPreco_Corrigido_Real                                                NaN
# Correlacao_Preco_Baixo_PetróleoPreco_Fechamento...                                                NaN
# Correlacao_Preco_Baixo_PetróleoPreco_Corrigido_...                                                NaN
# Correlacao_Preco_Baixo_PetróleoPreco_Abertura_Real                                                NaN
# Correlacao_Preco_Baixo_PetróleoPreco_Alta_Real                                                    NaN
# Correlacao_Preco_Baixo_PetróleoPreco_Baixo_Real                                                   NaN
# Correlacao_Preco_Baixo_PetróleoPreco_Fechamento...                                                NaN
# Correlacao_Preco_Baixo_PetróleoPreco_Corrigido_...                                                NaN
# Correlacao_Preco_Fechamento_PetróleoPreco_Corri...                                                NaN
# Correlacao_Preco_Fechamento_PetróleoPreco_Abert...                                                NaN
# Correlacao_Preco_Fechamento_PetróleoPreco_Alta_...                                                NaN
# Correlacao_Preco_Fechamento_PetróleoPreco_Baixo...                                                NaN
# Correlacao_Preco_Fechamento_PetróleoPreco_Fecha...                                                NaN
# Correlacao_Preco_Fechamento_PetróleoPreco_Corri...                                                NaN
# Correlacao_Preco_Corrigido_PetróleoPreco_Abertu...                                                NaN
# Correlacao_Preco_Corrigido_PetróleoPreco_Alta_Real                                                NaN
# Correlacao_Preco_Corrigido_PetróleoPreco_Baixo_...                                                NaN
# Correlacao_Preco_Corrigido_PetróleoPreco_Fecham...                                                NaN
# Correlacao_Preco_Corrigido_PetróleoPreco_Corrig...                                                NaN
# Correlacao_Preco_Abertura_RealPreco_Alta_Real                                                     NaN
# Correlacao_Preco_Abertura_RealPreco_Baixo_Real                                                    NaN
# Correlacao_Preco_Abertura_RealPreco_Fechamento_...                                                NaN
# Correlacao_Preco_Abertura_RealPreco_Corrigido_Real                                                NaN
# Correlacao_Preco_Alta_RealPreco_Baixo_Real                                                        NaN
# Correlacao_Preco_Alta_RealPreco_Fechamento_Real                                                   NaN
# Correlacao_Preco_Alta_RealPreco_Corrigido_Real                                                    NaN
# Correlacao_Preco_Baixo_RealPreco_Fechamento_Real                                                  NaN
# Correlacao_Preco_Baixo_RealPreco_Corrigido_Real                                                   NaN
# Correlacao_Preco_Fechamento_RealPreco_Corrigido...                                                NaN
#
# [133 rows x 133 columns]

# %%
# Selecionar os elementos da parte superior da diagonal
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))
upper
# Out:
#                                                     Preco_Abertura_Petrobras  \
# Preco_Abertura_Petrobras                                                 NaN
# Preco_Alta_Petrobras                                                     NaN
# Preco_Baixo_Petrobras                                                    NaN
# Preco_Fechamento_Petrobras                                               NaN
# Preco_Abertura_Petróleo                                                  NaN
# Preco_Alta_Petróleo                                                      NaN
# Preco_Baixo_Petróleo                                                     NaN
# Preco_Fechamento_Petróleo                                                NaN
# Preco_Corrigido_Petróleo                                                 NaN
# Preco_Abertura_Real                                                      NaN
# Preco_Alta_Real                                                          NaN
# Preco_Baixo_Real                                                         NaN
# Preco_Fechamento_Real                                                    NaN
# Preco_Corrigido_Real                                                     NaN
# Preco_Abertura_Petrobras_Media                                           NaN
# Preco_Alta_Petrobras_Media                                               NaN
# Preco_Baixo_Petrobras_Media                                              NaN
# Preco_Fechamento_Petrobras_Media                                         NaN
# Preco_Abertura_Petróleo_Media                                            NaN
# Preco_Alta_Petróleo_Media                                                NaN
# Preco_Baixo_Petróleo_Media                                               NaN
# Preco_Fechamento_Petróleo_Media                                          NaN
# Preco_Corrigido_Petróleo_Media                                           NaN
# Preco_Abertura_Real_Media                                                NaN
# Preco_Alta_Real_Media                                                    NaN
# Preco_Baixo_Real_Media                                                   NaN
# Preco_Fechamento_Real_Media                                              NaN
# Preco_Corrigido_Real_Media                                               NaN
# Preco_Abertura_Petrobras_%                                               NaN
# Preco_Alta_Petrobras_%                                                   NaN
# Preco_Baixo_Petrobras_%                                                  NaN
# Preco_Fechamento_Petrobras_%                                             NaN
# Preco_Abertura_Petróleo_%                                                NaN
# Preco_Alta_Petróleo_%                                                    NaN
# Preco_Baixo_Petróleo_%                                                   NaN
# Preco_Fechamento_Petróleo_%                                              NaN
# Preco_Corrigido_Petróleo_%                                               NaN
# Preco_Abertura_Real_%                                                    NaN
# Preco_Alta_Real_%                                                        NaN
# Preco_Baixo_Real_%                                                       NaN
# Preco_Fechamento_Real_%                                                  NaN
# Preco_Corrigido_Real_%                                                   NaN
# Correlacao_Preco_Abertura_PetrobrasPreco_Alta_P...                       NaN
# Correlacao_Preco_Abertura_PetrobrasPreco_Baixo_...                       NaN
# Correlacao_Preco_Abertura_PetrobrasPreco_Fecham...                       NaN
# Correlacao_Preco_Abertura_PetrobrasPreco_Abertu...                       NaN
# Correlacao_Preco_Abertura_PetrobrasPreco_Alta_P...                       NaN
# Correlacao_Preco_Abertura_PetrobrasPreco_Baixo_...                       NaN
# Correlacao_Preco_Abertura_PetrobrasPreco_Fecham...                       NaN
# Correlacao_Preco_Abertura_PetrobrasPreco_Corrig...                       NaN
# Correlacao_Preco_Abertura_PetrobrasPreco_Abertu...                       NaN
# Correlacao_Preco_Abertura_PetrobrasPreco_Alta_Real                       NaN
# Correlacao_Preco_Abertura_PetrobrasPreco_Baixo_...                       NaN
# Correlacao_Preco_Abertura_PetrobrasPreco_Fecham...                       NaN
# Correlacao_Preco_Abertura_PetrobrasPreco_Corrig...                       NaN
# Correlacao_Preco_Alta_PetrobrasPreco_Baixo_Petr...                       NaN
# Correlacao_Preco_Alta_PetrobrasPreco_Fechamento...                       NaN
# Correlacao_Preco_Alta_PetrobrasPreco_Abertura_P...                       NaN
# Correlacao_Preco_Alta_PetrobrasPreco_Alta_Petróleo                       NaN
# Correlacao_Preco_Alta_PetrobrasPreco_Baixo_Petr...                       NaN
# Correlacao_Preco_Alta_PetrobrasPreco_Fechamento...                       NaN
# Correlacao_Preco_Alta_PetrobrasPreco_Corrigido_...                       NaN
# Correlacao_Preco_Alta_PetrobrasPreco_Abertura_Real                       NaN
# Correlacao_Preco_Alta_PetrobrasPreco_Alta_Real                           NaN
# Correlacao_Preco_Alta_PetrobrasPreco_Baixo_Real                          NaN
# Correlacao_Preco_Alta_PetrobrasPreco_Fechamento...                       NaN
# Correlacao_Preco_Alta_PetrobrasPreco_Corrigido_...                       NaN
# Correlacao_Preco_Baixo_PetrobrasPreco_Fechament...                       NaN
# Correlacao_Preco_Baixo_PetrobrasPreco_Abertura_...                       NaN
# Correlacao_Preco_Baixo_PetrobrasPreco_Alta_Petr...                       NaN
# Correlacao_Preco_Baixo_PetrobrasPreco_Baixo_Pet...                       NaN
# Correlacao_Preco_Baixo_PetrobrasPreco_Fechament...                       NaN
# Correlacao_Preco_Baixo_PetrobrasPreco_Corrigido...                       NaN
# Correlacao_Preco_Baixo_PetrobrasPreco_Abertura_...                       NaN
# Correlacao_Preco_Baixo_PetrobrasPreco_Alta_Real                          NaN
# Correlacao_Preco_Baixo_PetrobrasPreco_Baixo_Real                         NaN
# Correlacao_Preco_Baixo_PetrobrasPreco_Fechament...                       NaN
# Correlacao_Preco_Baixo_PetrobrasPreco_Corrigido...                       NaN
# Correlacao_Preco_Fechamento_PetrobrasPreco_Aber...                       NaN
# Correlacao_Preco_Fechamento_PetrobrasPreco_Alta...                       NaN
# Correlacao_Preco_Fechamento_PetrobrasPreco_Baix...                       NaN
# Correlacao_Preco_Fechamento_PetrobrasPreco_Fech...                       NaN
# Correlacao_Preco_Fechamento_PetrobrasPreco_Corr...                       NaN
# Correlacao_Preco_Fechamento_PetrobrasPreco_Aber...                       NaN
# Correlacao_Preco_Fechamento_PetrobrasPreco_Alta...                       NaN
# Correlacao_Preco_Fechamento_PetrobrasPreco_Baix...                       NaN
# Correlacao_Preco_Fechamento_PetrobrasPreco_Fech...                       NaN
# Correlacao_Preco_Fechamento_PetrobrasPreco_Corr...                       NaN
# Correlacao_Preco_Abertura_PetróleoPreco_Alta_Pe...                       NaN
# Correlacao_Preco_Abertura_PetróleoPreco_Baixo_P...                       NaN
# Correlacao_Preco_Abertura_PetróleoPreco_Fechame...                       NaN
# Correlacao_Preco_Abertura_PetróleoPreco_Corrigi...                       NaN
# Correlacao_Preco_Abertura_PetróleoPreco_Abertur...                       NaN
# Correlacao_Preco_Abertura_PetróleoPreco_Alta_Real                        NaN
# Correlacao_Preco_Abertura_PetróleoPreco_Baixo_Real                       NaN
# Correlacao_Preco_Abertura_PetróleoPreco_Fechame...                       NaN
# Correlacao_Preco_Abertura_PetróleoPreco_Corrigi...                       NaN
# Correlacao_Preco_Alta_PetróleoPreco_Baixo_Petróleo                       NaN
# Correlacao_Preco_Alta_PetróleoPreco_Fechamento_...                       NaN
# Correlacao_Preco_Alta_PetróleoPreco_Corrigido_P...                       NaN
# Correlacao_Preco_Alta_PetróleoPreco_Abertura_Real                        NaN
# Correlacao_Preco_Alta_PetróleoPreco_Alta_Real                            NaN
# Correlacao_Preco_Alta_PetróleoPreco_Baixo_Real                           NaN
# Correlacao_Preco_Alta_PetróleoPreco_Fechamento_...                       NaN
# Correlacao_Preco_Alta_PetróleoPreco_Corrigido_Real                       NaN
# Correlacao_Preco_Baixo_PetróleoPreco_Fechamento...                       NaN
# Correlacao_Preco_Baixo_PetróleoPreco_Corrigido_...                       NaN
# Correlacao_Preco_Baixo_PetróleoPreco_Abertura_Real                       NaN
# Correlacao_Preco_Baixo_PetróleoPreco_Alta_Real                           NaN
# Correlacao_Preco_Baixo_PetróleoPreco_Baixo_Real                          NaN
# Correlacao_Preco_Baixo_PetróleoPreco_Fechamento...                       NaN
# Correlacao_Preco_Baixo_PetróleoPreco_Corrigido_...                       NaN
# Correlacao_Preco_Fechamento_PetróleoPreco_Corri...                       NaN
# Correlacao_Preco_Fechamento_PetróleoPreco_Abert...                       NaN
# Correlacao_Preco_Fechamento_PetróleoPreco_Alta_...                       NaN
# Correlacao_Preco_Fechamento_PetróleoPreco_Baixo...                       NaN
# Correlacao_Preco_Fechamento_PetróleoPreco_Fecha...                       NaN
# Correlacao_Preco_Fechamento_PetróleoPreco_Corri...                       NaN
# Correlacao_Preco_Corrigido_PetróleoPreco_Abertu...                       NaN
# Correlacao_Preco_Corrigido_PetróleoPreco_Alta_Real                       NaN
# Correlacao_Preco_Corrigido_PetróleoPreco_Baixo_...                       NaN
# Correlacao_Preco_Corrigido_PetróleoPreco_Fecham...                       NaN
# Correlacao_Preco_Corrigido_PetróleoPreco_Corrig...                       NaN
# Correlacao_Preco_Abertura_RealPreco_Alta_Real                            NaN
# Correlacao_Preco_Abertura_RealPreco_Baixo_Real                           NaN
# Correlacao_Preco_Abertura_RealPreco_Fechamento_...                       NaN
# Correlacao_Preco_Abertura_RealPreco_Corrigido_Real                       NaN
# Correlacao_Preco_Alta_RealPreco_Baixo_Real                               NaN
# Correlacao_Preco_Alta_RealPreco_Fechamento_Real                          NaN
# Correlacao_Preco_Alta_RealPreco_Corrigido_Real                           NaN
# Correlacao_Preco_Baixo_RealPreco_Fechamento_Real                         NaN
# Correlacao_Preco_Baixo_RealPreco_Corrigido_Real                          NaN
# Correlacao_Preco_Fechamento_RealPreco_Corrigido...                       NaN
#
#                                                     Preco_Alta_Petrobras  \
# Preco_Abertura_Petrobras                                        0.999363
# Preco_Alta_Petrobras                                                 NaN
# Preco_Baixo_Petrobras                                                NaN
# Preco_Fechamento_Petrobras                                           NaN
# Preco_Abertura_Petróleo                                              NaN
# Preco_Alta_Petróleo                                                  NaN
# Preco_Baixo_Petróleo                                                 NaN
# Preco_Fechamento_Petróleo                                            NaN
# Preco_Corrigido_Petróleo                                             NaN
# Preco_Abertura_Real                                                  NaN
# Preco_Alta_Real                                                      NaN
# Preco_Baixo_Real                                                     NaN
# Preco_Fechamento_Real                                                NaN
# Preco_Corrigido_Real                                                 NaN
# Preco_Abertura_Petrobras_Media                                       NaN
# Preco_Alta_Petrobras_Media                                           NaN
# Preco_Baixo_Petrobras_Media                                          NaN
# Preco_Fechamento_Petrobras_Media                                     NaN
# Preco_Abertura_Petróleo_Media                                        NaN
# Preco_Alta_Petróleo_Media                                            NaN
# Preco_Baixo_Petróleo_Media                                           NaN
# Preco_Fechamento_Petróleo_Media                                      NaN
# Preco_Corrigido_Petróleo_Media                                       NaN
# Preco_Abertura_Real_Media                                            NaN
# Preco_Alta_Real_Media                                                NaN
# Preco_Baixo_Real_Media                                               NaN
# Preco_Fechamento_Real_Media                                          NaN
# Preco_Corrigido_Real_Media                                           NaN
# Preco_Abertura_Petrobras_%                                           NaN
# Preco_Alta_Petrobras_%                                               NaN
# Preco_Baixo_Petrobras_%                                              NaN
# Preco_Fechamento_Petrobras_%                                         NaN
# Preco_Abertura_Petróleo_%                                            NaN
# Preco_Alta_Petróleo_%                                                NaN
# Preco_Baixo_Petróleo_%                                               NaN
# Preco_Fechamento_Petróleo_%                                          NaN
# Preco_Corrigido_Petróleo_%                                           NaN
# Preco_Abertura_Real_%                                                NaN
# Preco_Alta_Real_%                                                    NaN
# Preco_Baixo_Real_%                                                   NaN
# Preco_Fechamento_Real_%                                              NaN
# Preco_Corrigido_Real_%                                               NaN
# Correlacao_Preco_Abertura_PetrobrasPreco_Alta_P...                   NaN
# Correlacao_Preco_Abertura_PetrobrasPreco_Baixo_...                   NaN
# Correlacao_Preco_Abertura_PetrobrasPreco_Fecham...                   NaN
# Correlacao_Preco_Abertura_PetrobrasPreco_Abertu...                   NaN
# Correlacao_Preco_Abertura_PetrobrasPreco_Alta_P...                   NaN
# Correlacao_Preco_Abertura_PetrobrasPreco_Baixo_...                   NaN
# Correlacao_Preco_Abertura_PetrobrasPreco_Fecham...                   NaN
# Correlacao_Preco_Abertura_PetrobrasPreco_Corrig...                   NaN
# Correlacao_Preco_Abertura_PetrobrasPreco_Abertu...                   NaN
# Correlacao_Preco_Abertura_PetrobrasPreco_Alta_Real                   NaN
# Correlacao_Preco_Abertura_PetrobrasPreco_Baixo_...                   NaN
# Correlacao_Preco_Abertura_PetrobrasPreco_Fecham...                   NaN
# Correlacao_Preco_Abertura_PetrobrasPreco_Corrig...                   NaN
# Correlacao_Preco_Alta_PetrobrasPreco_Baixo_Petr...                   NaN
# Correlacao_Preco_Alta_PetrobrasPreco_Fechamento...                   NaN
# Correlacao_Preco_Alta_PetrobrasPreco_Abertura_P...                   NaN
# Correlacao_Preco_Alta_PetrobrasPreco_Alta_Petróleo                   NaN
# Correlacao_Preco_Alta_PetrobrasPreco_Baixo_Petr...                   NaN
# Correlacao_Preco_Alta_PetrobrasPreco_Fechamento...                   NaN
# Correlacao_Preco_Alta_PetrobrasPreco_Corrigido_...                   NaN
# Correlacao_Preco_Alta_PetrobrasPreco_Abertura_Real                   NaN
# Correlacao_Preco_Alta_PetrobrasPreco_Alta_Real                       NaN
# Correlacao_Preco_Alta_PetrobrasPreco_Baixo_Real                      NaN
# Correlacao_Preco_Alta_PetrobrasPreco_Fechamento...                   NaN
# Correlacao_Preco_Alta_PetrobrasPreco_Corrigido_...                   NaN
# Correlacao_Preco_Baixo_PetrobrasPreco_Fechament...                   NaN
# Correlacao_Preco_Baixo_PetrobrasPreco_Abertura_...                   NaN
# Correlacao_Preco_Baixo_PetrobrasPreco_Alta_Petr...                   NaN
# Correlacao_Preco_Baixo_PetrobrasPreco_Baixo_Pet...                   NaN
# Correlacao_Preco_Baixo_PetrobrasPreco_Fechament...                   NaN
# Correlacao_Preco_Baixo_PetrobrasPreco_Corrigido...                   NaN
# Correlacao_Preco_Baixo_PetrobrasPreco_Abertura_...                   NaN
# Correlacao_Preco_Baixo_PetrobrasPreco_Alta_Real                      NaN
# Correlacao_Preco_Baixo_PetrobrasPreco_Baixo_Real                     NaN
# Correlacao_Preco_Baixo_PetrobrasPreco_Fechament...                   NaN
# Correlacao_Preco_Baixo_PetrobrasPreco_Corrigido...                   NaN
# Correlacao_Preco_Fechamento_PetrobrasPreco_Aber...                   NaN
# Correlacao_Preco_Fechamento_PetrobrasPreco_Alta...                   NaN
# Correlacao_Preco_Fechamento_PetrobrasPreco_Baix...                   NaN
# Correlacao_Preco_Fechamento_PetrobrasPreco_Fech...                   NaN
# Correlacao_Preco_Fechamento_PetrobrasPreco_Corr...                   NaN
# Correlacao_Preco_Fechamento_PetrobrasPreco_Aber...                   NaN
# Correlacao_Preco_Fechamento_PetrobrasPreco_Alta...                   NaN
# Correlacao_Preco_Fechamento_PetrobrasPreco_Baix...                   NaN
# Correlacao_Preco_Fechamento_PetrobrasPreco_Fech...                   NaN
# Correlacao_Preco_Fechamento_PetrobrasPreco_Corr...                   NaN
# Correlacao_Preco_Abertura_PetróleoPreco_Alta_Pe...                   NaN
# Correlacao_Preco_Abertura_PetróleoPreco_Baixo_P...                   NaN
# Correlacao_Preco_Abertura_PetróleoPreco_Fechame...                   NaN
# Correlacao_Preco_Abertura_PetróleoPreco_Corrigi...                   NaN
# Correlacao_Preco_Abertura_PetróleoPreco_Abertur...                   NaN
# Correlacao_Preco_Abertura_PetróleoPreco_Alta_Real                    NaN
# Correlacao_Preco_Abertura_PetróleoPreco_Baixo_Real                   NaN
# Correlacao_Preco_Abertura_PetróleoPreco_Fechame...                   NaN
# Correlacao_Preco_Abertura_PetróleoPreco_Corrigi...                   NaN
# Correlacao_Preco_Alta_PetróleoPreco_Baixo_Petróleo                   NaN
# Correlacao_Preco_Alta_PetróleoPreco_Fechamento_...                   NaN
# Correlacao_Preco_Alta_PetróleoPreco_Corrigido_P...                   NaN
# Correlacao_Preco_Alta_PetróleoPreco_Abertura_Real                    NaN
# Correlacao_Preco_Alta_PetróleoPreco_Alta_Real                        NaN
# Correlacao_Preco_Alta_PetróleoPreco_Baixo_Real                       NaN
# Correlacao_Preco_Alta_PetróleoPreco_Fechamento_...                   NaN
# Correlacao_Preco_Alta_PetróleoPreco_Corrigido_Real                   NaN
# Correlacao_Preco_Baixo_PetróleoPreco_Fechamento...                   NaN
# Correlacao_Preco_Baixo_PetróleoPreco_Corrigido_...                   NaN
# Correlacao_Preco_Baixo_PetróleoPreco_Abertura_Real                   NaN
# Correlacao_Preco_Baixo_PetróleoPreco_Alta_Real                       NaN
# Correlacao_Preco_Baixo_PetróleoPreco_Baixo_Real                      NaN
# Correlacao_Preco_Baixo_PetróleoPreco_Fechamento...                   NaN
# Correlacao_Preco_Baixo_PetróleoPreco_Corrigido_...                   NaN
# Correlacao_Preco_Fechamento_PetróleoPreco_Corri...                   NaN
# Correlacao_Preco_Fechamento_PetróleoPreco_Abert...                   NaN
# Correlacao_Preco_Fechamento_PetróleoPreco_Alta_...                   NaN
# Correlacao_Preco_Fechamento_PetróleoPreco_Baixo...                   NaN
# Correlacao_Preco_Fechamento_PetróleoPreco_Fecha...                   NaN
# Correlacao_Preco_Fechamento_PetróleoPreco_Corri...                   NaN
# Correlacao_Preco_Corrigido_PetróleoPreco_Abertu...                   NaN
# Correlacao_Preco_Corrigido_PetróleoPreco_Alta_Real                   NaN
# Correlacao_Preco_Corrigido_PetróleoPreco_Baixo_...                   NaN
# Correlacao_Preco_Corrigido_PetróleoPreco_Fecham...                   NaN
# Correlacao_Preco_Corrigido_PetróleoPreco_Corrig...                   NaN
# Correlacao_Preco_Abertura_RealPreco_Alta_Real                        NaN
# Correlacao_Preco_Abertura_RealPreco_Baixo_Real                       NaN
# Correlacao_Preco_Abertura_RealPreco_Fechamento_...                   NaN
# Correlacao_Preco_Abertura_RealPreco_Corrigido_Real                   NaN
# Correlacao_Preco_Alta_RealPreco_Baixo_Real                           NaN
# Correlacao_Preco_Alta_RealPreco_Fechamento_Real                      NaN
# Correlacao_Preco_Alta_RealPreco_Corrigido_Real                       NaN
# Correlacao_Preco_Baixo_RealPreco_Fechamento_Real                     NaN
# Correlacao_Preco_Baixo_RealPreco_Corrigido_Real                      NaN
# Correlacao_Preco_Fechamento_RealPreco_Corrigido...                   NaN
#
#                                                     Preco_Baixo_Petrobras  \
# Preco_Abertura_Petrobras                                         0.998994
# Preco_Alta_Petrobras                                             0.998735
# Preco_Baixo_Petrobras                                                 NaN
# Preco_Fechamento_Petrobras                                            NaN
# Preco_Abertura_Petróleo                                               NaN
# Preco_Alta_Petróleo                                                   NaN
# Preco_Baixo_Petróleo                                                  NaN
# Preco_Fechamento_Petróleo                                             NaN
# Preco_Corrigido_Petróleo                                              NaN
# Preco_Abertura_Real                                                   NaN
# Preco_Alta_Real                                                       NaN
# Preco_Baixo_Real                                                      NaN
# Preco_Fechamento_Real                                                 NaN
# Preco_Corrigido_Real                                                  NaN
# Preco_Abertura_Petrobras_Media                                        NaN
# Preco_Alta_Petrobras_Media                                            NaN
# Preco_Baixo_Petrobras_Media                                           NaN
# Preco_Fechamento_Petrobras_Media                                      NaN
# Preco_Abertura_Petróleo_Media                                         NaN
# Preco_Alta_Petróleo_Media                                             NaN
# Preco_Baixo_Petróleo_Media                                            NaN
# Preco_Fechamento_Petróleo_Media                                       NaN
# Preco_Corrigido_Petróleo_Media                                        NaN
# Preco_Abertura_Real_Media                                             NaN
# Preco_Alta_Real_Media                                                 NaN
# Preco_Baixo_Real_Media                                                NaN
# Preco_Fechamento_Real_Media                                           NaN
# Preco_Corrigido_Real_Media                                            NaN
# Preco_Abertura_Petrobras_%                                            NaN
# Preco_Alta_Petrobras_%                                                NaN
# Preco_Baixo_Petrobras_%                                               NaN
# Preco_Fechamento_Petrobras_%                                          NaN
# Preco_Abertura_Petróleo_%                                             NaN
# Preco_Alta_Petróleo_%                                                 NaN
# Preco_Baixo_Petróleo_%                                                NaN
# Preco_Fechamento_Petróleo_%                                           NaN
# Preco_Corrigido_Petróleo_%                                            NaN
# Preco_Abertura_Real_%                                                 NaN
# Preco_Alta_Real_%                                                     NaN
# Preco_Baixo_Real_%                                                    NaN
# Preco_Fechamento_Real_%                                               NaN
# Preco_Corrigido_Real_%                                                NaN
# Correlacao_Preco_Abertura_PetrobrasPreco_Alta_P...                    NaN
# Correlacao_Preco_Abertura_PetrobrasPreco_Baixo_...                    NaN
# Correlacao_Preco_Abertura_PetrobrasPreco_Fecham...                    NaN
# Correlacao_Preco_Abertura_PetrobrasPreco_Abertu...                    NaN
# Correlacao_Preco_Abertura_PetrobrasPreco_Alta_P...                    NaN
# Correlacao_Preco_Abertura_PetrobrasPreco_Baixo_...                    NaN
# Correlacao_Preco_Abertura_PetrobrasPreco_Fecham...                    NaN
# Correlacao_Preco_Abertura_PetrobrasPreco_Corrig...                    NaN
# Correlacao_Preco_Abertura_PetrobrasPreco_Abertu...                    NaN
# Correlacao_Preco_Abertura_PetrobrasPreco_Alta_Real                    NaN
# Correlacao_Preco_Abertura_PetrobrasPreco_Baixo_...                    NaN
# Correlacao_Preco_Abertura_PetrobrasPreco_Fecham...                    NaN
# Correlacao_Preco_Abertura_PetrobrasPreco_Corrig...                    NaN
# Correlacao_Preco_Alta_PetrobrasPreco_Baixo_Petr...                    NaN
# Correlacao_Preco_Alta_PetrobrasPreco_Fechamento...                    NaN
# Correlacao_Preco_Alta_PetrobrasPreco_Abertura_P...                    NaN
# Correlacao_Preco_Alta_PetrobrasPreco_Alta_Petróleo                    NaN
# Correlacao_Preco_Alta_PetrobrasPreco_Baixo_Petr...                    NaN
# Correlacao_Preco_Alta_PetrobrasPreco_Fechamento...                    NaN
# Correlacao_Preco_Alta_PetrobrasPreco_Corrigido_...                    NaN
# Correlacao_Preco_Alta_PetrobrasPreco_Abertura_Real                    NaN
# Correlacao_Preco_Alta_PetrobrasPreco_Alta_Real                        NaN
# Correlacao_Preco_Alta_PetrobrasPreco_Baixo_Real                       NaN
# Correlacao_Preco_Alta_PetrobrasPreco_Fechamento...                    NaN
# Correlacao_Preco_Alta_PetrobrasPreco_Corrigido_...                    NaN
# Correlacao_Preco_Baixo_PetrobrasPreco_Fechament...                    NaN
# Correlacao_Preco_Baixo_PetrobrasPreco_Abertura_...                    NaN
# Correlacao_Preco_Baixo_PetrobrasPreco_Alta_Petr...                    NaN
# Correlacao_Preco_Baixo_PetrobrasPreco_Baixo_Pet...                    NaN
# Correlacao_Preco_Baixo_PetrobrasPreco_Fechament...                    NaN
# Correlacao_Preco_Baixo_PetrobrasPreco_Corrigido...                    NaN
# Correlacao_Preco_Baixo_PetrobrasPreco_Abertura_...                    NaN
# Correlacao_Preco_Baixo_PetrobrasPreco_Alta_Real                       NaN
# Correlacao_Preco_Baixo_PetrobrasPreco_Baixo_Real                      NaN
# Correlacao_Preco_Baixo_PetrobrasPreco_Fechament...                    NaN
# Correlacao_Preco_Baixo_PetrobrasPreco_Corrigido...                    NaN
# Correlacao_Preco_Fechamento_PetrobrasPreco_Aber...                    NaN
# Correlacao_Preco_Fechamento_PetrobrasPreco_Alta...                    NaN
# Correlacao_Preco_Fechamento_PetrobrasPreco_Baix...                    NaN
# Correlacao_Preco_Fechamento_PetrobrasPreco_Fech...                    NaN
# Correlacao_Preco_Fechamento_PetrobrasPreco_Corr...                    NaN
# Correlacao_Preco_Fechamento_PetrobrasPreco_Aber...                    NaN
# Correlacao_Preco_Fechamento_PetrobrasPreco_Alta...                    NaN
# Correlacao_Preco_Fechamento_PetrobrasPreco_Baix...                    NaN
# Correlacao_Preco_Fechamento_PetrobrasPreco_Fech...                    NaN
# Correlacao_Preco_Fechamento_PetrobrasPreco_Corr...                    NaN
# Correlacao_Preco_Abertura_PetróleoPreco_Alta_Pe...                    NaN
# Correlacao_Preco_Abertura_PetróleoPreco_Baixo_P...                    NaN
# Correlacao_Preco_Abertura_PetróleoPreco_Fechame...                    NaN
# Correlacao_Preco_Abertura_PetróleoPreco_Corrigi...                    NaN
# Correlacao_Preco_Abertura_PetróleoPreco_Abertur...                    NaN
# Correlacao_Preco_Abertura_PetróleoPreco_Alta_Real                     NaN
# Correlacao_Preco_Abertura_PetróleoPreco_Baixo_Real                    NaN
# Correlacao_Preco_Abertura_PetróleoPreco_Fechame...                    NaN
# Correlacao_Preco_Abertura_PetróleoPreco_Corrigi...                    NaN
# Correlacao_Preco_Alta_PetróleoPreco_Baixo_Petróleo                    NaN
# Correlacao_Preco_Alta_PetróleoPreco_Fechamento_...                    NaN
# Correlacao_Preco_Alta_PetróleoPreco_Corrigido_P...                    NaN
# Correlacao_Preco_Alta_PetróleoPreco_Abertura_Real                     NaN
# Correlacao_Preco_Alta_PetróleoPreco_Alta_Real                         NaN
# Correlacao_Preco_Alta_PetróleoPreco_Baixo_Real                        NaN
# Correlacao_Preco_Alta_PetróleoPreco_Fechamento_...                    NaN
# Correlacao_Preco_Alta_PetróleoPreco_Corrigido_Real                    NaN
# Correlacao_Preco_Baixo_PetróleoPreco_Fechamento...                    NaN
# Correlacao_Preco_Baixo_PetróleoPreco_Corrigido_...                    NaN
# Correlacao_Preco_Baixo_PetróleoPreco_Abertura_Real                    NaN
# Correlacao_Preco_Baixo_PetróleoPreco_Alta_Real                        NaN
# Correlacao_Preco_Baixo_PetróleoPreco_Baixo_Real                       NaN
# Correlacao_Preco_Baixo_PetróleoPreco_Fechamento...                    NaN
# Correlacao_Preco_Baixo_PetróleoPreco_Corrigido_...                    NaN
# Correlacao_Preco_Fechamento_PetróleoPreco_Corri...                    NaN
# Correlacao_Preco_Fechamento_PetróleoPreco_Abert...                    NaN
# Correlacao_Preco_Fechamento_PetróleoPreco_Alta_...                    NaN
# Correlacao_Preco_Fechamento_PetróleoPreco_Baixo...                    NaN
# Correlacao_Preco_Fechamento_PetróleoPreco_Fecha...                    NaN
# Correlacao_Preco_Fechamento_PetróleoPreco_Corri...                    NaN
# Correlacao_Preco_Corrigido_PetróleoPreco_Abertu...                    NaN
# Correlacao_Preco_Corrigido_PetróleoPreco_Alta_Real                    NaN
# Correlacao_Preco_Corrigido_PetróleoPreco_Baixo_...                    NaN
# Correlacao_Preco_Corrigido_PetróleoPreco_Fecham...                    NaN
# Correlacao_Preco_Corrigido_PetróleoPreco_Corrig...                    NaN
# Correlacao_Preco_Abertura_RealPreco_Alta_Real                         NaN
# Correlacao_Preco_Abertura_RealPreco_Baixo_Real                        NaN
# Correlacao_Preco_Abertura_RealPreco_Fechamento_...                    NaN
# Correlacao_Preco_Abertura_RealPreco_Corrigido_Real                    NaN
# Correlacao_Preco_Alta_RealPreco_Baixo_Real                            NaN
# Correlacao_Preco_Alta_RealPreco_Fechamento_Real                       NaN
# Correlacao_Preco_Alta_RealPreco_Corrigido_Real                        NaN
# Correlacao_Preco_Baixo_RealPreco_Fechamento_Real                      NaN
# Correlacao_Preco_Baixo_RealPreco_Corrigido_Real                       NaN
# Correlacao_Preco_Fechamento_RealPreco_Corrigido...                    NaN
#
#                                                     Preco_Fechamento_Petrobras  \
# Preco_Abertura_Petrobras                                              0.998407
# Preco_Alta_Petrobras                                                  0.999107
# Preco_Baixo_Petrobras                                                 0.999276
# Preco_Fechamento_Petrobras                                                 NaN
# Preco_Abertura_Petróleo                                                    NaN
# Preco_Alta_Petróleo                                                        NaN
# Preco_Baixo_Petróleo                                                       NaN
# Preco_Fechamento_Petróleo                                                  NaN
# Preco_Corrigido_Petróleo                                                   NaN
# Preco_Abertura_Real                                                        NaN
# Preco_Alta_Real                                                            NaN
# Preco_Baixo_Real                                                           NaN
# Preco_Fechamento_Real                                                      NaN
# Preco_Corrigido_Real                                                       NaN
# Preco_Abertura_Petrobras_Media                                             NaN
# Preco_Alta_Petrobras_Media                                                 NaN
# Preco_Baixo_Petrobras_Media                                                NaN
# Preco_Fechamento_Petrobras_Media                                           NaN
# Preco_Abertura_Petróleo_Media                                              NaN
# Preco_Alta_Petróleo_Media                                                  NaN
# Preco_Baixo_Petróleo_Media                                                 NaN
# Preco_Fechamento_Petróleo_Media                                            NaN
# Preco_Corrigido_Petróleo_Media                                             NaN
# Preco_Abertura_Real_Media                                                  NaN
# Preco_Alta_Real_Media                                                      NaN
# Preco_Baixo_Real_Media                                                     NaN
# Preco_Fechamento_Real_Media                                                NaN
# Preco_Corrigido_Real_Media                                                 NaN
# Preco_Abertura_Petrobras_%                                                 NaN
# Preco_Alta_Petrobras_%                                                     NaN
# Preco_Baixo_Petrobras_%                                                    NaN
# Preco_Fechamento_Petrobras_%                                               NaN
# Preco_Abertura_Petróleo_%                                                  NaN
# Preco_Alta_Petróleo_%                                                      NaN
# Preco_Baixo_Petróleo_%                                                     NaN
# Preco_Fechamento_Petróleo_%                                                NaN
# Preco_Corrigido_Petróleo_%                                                 NaN
# Preco_Abertura_Real_%                                                      NaN
# Preco_Alta_Real_%                                                          NaN
# Preco_Baixo_Real_%                                                         NaN
# Preco_Fechamento_Real_%                                                    NaN
# Preco_Corrigido_Real_%                                                     NaN
# Correlacao_Preco_Abertura_PetrobrasPreco_Alta_P...                         NaN
# Correlacao_Preco_Abertura_PetrobrasPreco_Baixo_...                         NaN
# Correlacao_Preco_Abertura_PetrobrasPreco_Fecham...                         NaN
# Correlacao_Preco_Abertura_PetrobrasPreco_Abertu...                         NaN
# Correlacao_Preco_Abertura_PetrobrasPreco_Alta_P...                         NaN
# Correlacao_Preco_Abertura_PetrobrasPreco_Baixo_...                         NaN
# Correlacao_Preco_Abertura_PetrobrasPreco_Fecham...                         NaN
# Correlacao_Preco_Abertura_PetrobrasPreco_Corrig...                         NaN
# Correlacao_Preco_Abertura_PetrobrasPreco_Abertu...                         NaN
# Correlacao_Preco_Abertura_PetrobrasPreco_Alta_Real                         NaN
# Correlacao_Preco_Abertura_PetrobrasPreco_Baixo_...                         NaN
# Correlacao_Preco_Abertura_PetrobrasPreco_Fecham...                         NaN
# Correlacao_Preco_Abertura_PetrobrasPreco_Corrig...                         NaN
# Correlacao_Preco_Alta_PetrobrasPreco_Baixo_Petr...                         NaN
# Correlacao_Preco_Alta_PetrobrasPreco_Fechamento...                         NaN
# Correlacao_Preco_Alta_PetrobrasPreco_Abertura_P...                         NaN
# Correlacao_Preco_Alta_PetrobrasPreco_Alta_Petróleo                         NaN
# Correlacao_Preco_Alta_PetrobrasPreco_Baixo_Petr...                         NaN
# Correlacao_Preco_Alta_PetrobrasPreco_Fechamento...                         NaN
# Correlacao_Preco_Alta_PetrobrasPreco_Corrigido_...                         NaN
# Correlacao_Preco_Alta_PetrobrasPreco_Abertura_Real                         NaN
# Correlacao_Preco_Alta_PetrobrasPreco_Alta_Real                             NaN
# Correlacao_Preco_Alta_PetrobrasPreco_Baixo_Real                            NaN
# Correlacao_Preco_Alta_PetrobrasPreco_Fechamento...                         NaN
# Correlacao_Preco_Alta_PetrobrasPreco_Corrigido_...                         NaN
# Correlacao_Preco_Baixo_PetrobrasPreco_Fechament...                         NaN
# Correlacao_Preco_Baixo_PetrobrasPreco_Abertura_...                         NaN
# Correlacao_Preco_Baixo_PetrobrasPreco_Alta_Petr...                         NaN
# Correlacao_Preco_Baixo_PetrobrasPreco_Baixo_Pet...                         NaN
# Correlacao_Preco_Baixo_PetrobrasPreco_Fechament...                         NaN
# Correlacao_Preco_Baixo_PetrobrasPreco_Corrigido...                         NaN
# Correlacao_Preco_Baixo_PetrobrasPreco_Abertura_...                         NaN
# Correlacao_Preco_Baixo_PetrobrasPreco_Alta_Real                            NaN
# Correlacao_Preco_Baixo_PetrobrasPreco_Baixo_Real                           NaN
# Correlacao_Preco_Baixo_PetrobrasPreco_Fechament...                         NaN
# Correlacao_Preco_Baixo_PetrobrasPreco_Corrigido...                         NaN
# Correlacao_Preco_Fechamento_PetrobrasPreco_Aber...                         NaN
# Correlacao_Preco_Fechamento_PetrobrasPreco_Alta...                         NaN
# Correlacao_Preco_Fechamento_PetrobrasPreco_Baix...                         NaN
# Correlacao_Preco_Fechamento_PetrobrasPreco_Fech...                         NaN
# Correlacao_Preco_Fechamento_PetrobrasPreco_Corr...                         NaN
# Correlacao_Preco_Fechamento_PetrobrasPreco_Aber...                         NaN
# Correlacao_Preco_Fechamento_PetrobrasPreco_Alta...                         NaN
# Correlacao_Preco_Fechamento_PetrobrasPreco_Baix...                         NaN
# Correlacao_Preco_Fechamento_PetrobrasPreco_Fech...                         NaN
# Correlacao_Preco_Fechamento_PetrobrasPreco_Corr...                         NaN
# Correlacao_Preco_Abertura_PetróleoPreco_Alta_Pe...                         NaN
# Correlacao_Preco_Abertura_PetróleoPreco_Baixo_P...                         NaN
# Correlacao_Preco_Abertura_PetróleoPreco_Fechame...                         NaN
# Correlacao_Preco_Abertura_PetróleoPreco_Corrigi...                         NaN
# Correlacao_Preco_Abertura_PetróleoPreco_Abertur...                         NaN
# Correlacao_Preco_Abertura_PetróleoPreco_Alta_Real                          NaN
# Correlacao_Preco_Abertura_PetróleoPreco_Baixo_Real                         NaN
# Correlacao_Preco_Abertura_PetróleoPreco_Fechame...                         NaN
# Correlacao_Preco_Abertura_PetróleoPreco_Corrigi...                         NaN
# Correlacao_Preco_Alta_PetróleoPreco_Baixo_Petróleo                         NaN
# Correlacao_Preco_Alta_PetróleoPreco_Fechamento_...                         NaN
# Correlacao_Preco_Alta_PetróleoPreco_Corrigido_P...                         NaN
# Correlacao_Preco_Alta_PetróleoPreco_Abertura_Real                          NaN
# Correlacao_Preco_Alta_PetróleoPreco_Alta_Real                              NaN
# Correlacao_Preco_Alta_PetróleoPreco_Baixo_Real                             NaN
# Correlacao_Preco_Alta_PetróleoPreco_Fechamento_...                         NaN
# Correlacao_Preco_Alta_PetróleoPreco_Corrigido_Real                         NaN
# Correlacao_Preco_Baixo_PetróleoPreco_Fechamento...                         NaN
# Correlacao_Preco_Baixo_PetróleoPreco_Corrigido_...                         NaN
# Correlacao_Preco_Baixo_PetróleoPreco_Abertura_Real                         NaN
# Correlacao_Preco_Baixo_PetróleoPreco_Alta_Real                             NaN
# Correlacao_Preco_Baixo_PetróleoPreco_Baixo_Real                            NaN
# Correlacao_Preco_Baixo_PetróleoPreco_Fechamento...                         NaN
# Correlacao_Preco_Baixo_PetróleoPreco_Corrigido_...                         NaN
# Correlacao_Preco_Fechamento_PetróleoPreco_Corri...                         NaN
# Correlacao_Preco_Fechamento_PetróleoPreco_Abert...                         NaN
# Correlacao_Preco_Fechamento_PetróleoPreco_Alta_...                         NaN
# Correlacao_Preco_Fechamento_PetróleoPreco_Baixo...                         NaN
# Correlacao_Preco_Fechamento_PetróleoPreco_Fecha...                         NaN
# Correlacao_Preco_Fechamento_PetróleoPreco_Corri...                         NaN
# Correlacao_Preco_Corrigido_PetróleoPreco_Abertu...                         NaN
# Correlacao_Preco_Corrigido_PetróleoPreco_Alta_Real                         NaN
# Correlacao_Preco_Corrigido_PetróleoPreco_Baixo_...                         NaN
# Correlacao_Preco_Corrigido_PetróleoPreco_Fecham...                         NaN
# Correlacao_Preco_Corrigido_PetróleoPreco_Corrig...                         NaN
# Correlacao_Preco_Abertura_RealPreco_Alta_Real                              NaN
# Correlacao_Preco_Abertura_RealPreco_Baixo_Real                             NaN
# Correlacao_Preco_Abertura_RealPreco_Fechamento_...                         NaN
# Correlacao_Preco_Abertura_RealPreco_Corrigido_Real                         NaN
# Correlacao_Preco_Alta_RealPreco_Baixo_Real                                 NaN
# Correlacao_Preco_Alta_RealPreco_Fechamento_Real                            NaN
# Correlacao_Preco_Alta_RealPreco_Corrigido_Real                             NaN
# Correlacao_Preco_Baixo_RealPreco_Fechamento_Real                           NaN
# Correlacao_Preco_Baixo_RealPreco_Corrigido_Real                            NaN
# Correlacao_Preco_Fechamento_RealPreco_Corrigido...                         NaN
#
#                                                     Preco_Abertura_Petróleo  \
# Preco_Abertura_Petrobras                                           0.586942
# Preco_Alta_Petrobras                                               0.584659
# Preco_Baixo_Petrobras                                              0.589234
# Preco_Fechamento_Petrobras                                         0.586594
# Preco_Abertura_Petróleo                                                 NaN
# Preco_Alta_Petróleo                                                     NaN
# Preco_Baixo_Petróleo                                                    NaN
# Preco_Fechamento_Petróleo                                               NaN
# Preco_Corrigido_Petróleo                                                NaN
# Preco_Abertura_Real                                                     NaN
# Preco_Alta_Real                                                         NaN
# Preco_Baixo_Real                                                        NaN
# Preco_Fechamento_Real                                                   NaN
# Preco_Corrigido_Real                                                    NaN
# Preco_Abertura_Petrobras_Media                                          NaN
# Preco_Alta_Petrobras_Media                                              NaN
# Preco_Baixo_Petrobras_Media                                             NaN
# Preco_Fechamento_Petrobras_Media                                        NaN
# Preco_Abertura_Petróleo_Media                                           NaN
# Preco_Alta_Petróleo_Media                                               NaN
# Preco_Baixo_Petróleo_Media                                              NaN
# Preco_Fechamento_Petróleo_Media                                         NaN
# Preco_Corrigido_Petróleo_Media                                          NaN
# Preco_Abertura_Real_Media                                               NaN
# Preco_Alta_Real_Media                                                   NaN
# Preco_Baixo_Real_Media                                                  NaN
# Preco_Fechamento_Real_Media                                             NaN
# Preco_Corrigido_Real_Media                                              NaN
# Preco_Abertura_Petrobras_%                                              NaN
# Preco_Alta_Petrobras_%                                                  NaN
# Preco_Baixo_Petrobras_%                                                 NaN
# Preco_Fechamento_Petrobras_%                                            NaN
# Preco_Abertura_Petróleo_%                                               NaN
# Preco_Alta_Petróleo_%                                                   NaN
# Preco_Baixo_Petróleo_%                                                  NaN
# Preco_Fechamento_Petróleo_%                                             NaN
# Preco_Corrigido_Petróleo_%                                              NaN
# Preco_Abertura_Real_%                                                   NaN
# Preco_Alta_Real_%                                                       NaN
# Preco_Baixo_Real_%                                                      NaN
# Preco_Fechamento_Real_%                                                 NaN
# Preco_Corrigido_Real_%                                                  NaN
# Correlacao_Preco_Abertura_PetrobrasPreco_Alta_P...                      NaN
# Correlacao_Preco_Abertura_PetrobrasPreco_Baixo_...                      NaN
# Correlacao_Preco_Abertura_PetrobrasPreco_Fecham...                      NaN
# Correlacao_Preco_Abertura_PetrobrasPreco_Abertu...                      NaN
# Correlacao_Preco_Abertura_PetrobrasPreco_Alta_P...                      NaN
# Correlacao_Preco_Abertura_PetrobrasPreco_Baixo_...                      NaN
# Correlacao_Preco_Abertura_PetrobrasPreco_Fecham...                      NaN
# Correlacao_Preco_Abertura_PetrobrasPreco_Corrig...                      NaN
# Correlacao_Preco_Abertura_PetrobrasPreco_Abertu...                      NaN
# Correlacao_Preco_Abertura_PetrobrasPreco_Alta_Real                      NaN
# Correlacao_Preco_Abertura_PetrobrasPreco_Baixo_...                      NaN
# Correlacao_Preco_Abertura_PetrobrasPreco_Fecham...                      NaN
# Correlacao_Preco_Abertura_PetrobrasPreco_Corrig...                      NaN
# Correlacao_Preco_Alta_PetrobrasPreco_Baixo_Petr...                      NaN
# Correlacao_Preco_Alta_PetrobrasPreco_Fechamento...                      NaN
# Correlacao_Preco_Alta_PetrobrasPreco_Abertura_P...                      NaN
# Correlacao_Preco_Alta_PetrobrasPreco_Alta_Petróleo                      NaN
# Correlacao_Preco_Alta_PetrobrasPreco_Baixo_Petr...                      NaN
# Correlacao_Preco_Alta_PetrobrasPreco_Fechamento...                      NaN
# Correlacao_Preco_Alta_PetrobrasPreco_Corrigido_...                      NaN
# Correlacao_Preco_Alta_PetrobrasPreco_Abertura_Real                      NaN
# Correlacao_Preco_Alta_PetrobrasPreco_Alta_Real                          NaN
# Correlacao_Preco_Alta_PetrobrasPreco_Baixo_Real                         NaN
# Correlacao_Preco_Alta_PetrobrasPreco_Fechamento...                      NaN
# Correlacao_Preco_Alta_PetrobrasPreco_Corrigido_...                      NaN
# Correlacao_Preco_Baixo_PetrobrasPreco_Fechament...                      NaN
# Correlacao_Preco_Baixo_PetrobrasPreco_Abertura_...                      NaN
# Correlacao_Preco_Baixo_PetrobrasPreco_Alta_Petr...                      NaN
# Correlacao_Preco_Baixo_PetrobrasPreco_Baixo_Pet...                      NaN
# Correlacao_Preco_Baixo_PetrobrasPreco_Fechament...                      NaN
# ...
# Correlacao_Preco_Corrigido_PetróleoPreco_Abertu...                                         0.054390
# Correlacao_Preco_Corrigido_PetróleoPreco_Alta_Real                                         0.027230
# Correlacao_Preco_Corrigido_PetróleoPreco_Baixo_...                                         0.077530
# Correlacao_Preco_Corrigido_PetróleoPreco_Fecham...                                         0.054560
# Correlacao_Preco_Corrigido_PetróleoPreco_Corrig...                                         0.054560
# Correlacao_Preco_Abertura_RealPreco_Alta_Real                                              0.702962
# Correlacao_Preco_Abertura_RealPreco_Baixo_Real                                             0.995600
# Correlacao_Preco_Abertura_RealPreco_Fechamento_...                                         0.109485
# Correlacao_Preco_Abertura_RealPreco_Corrigido_Real                                         0.109485
# Correlacao_Preco_Alta_RealPreco_Baixo_Real                                                 0.818279
# Correlacao_Preco_Alta_RealPreco_Fechamento_Real                                            0.702965
# Correlacao_Preco_Alta_RealPreco_Corrigido_Real                                             0.702965
# Correlacao_Preco_Baixo_RealPreco_Fechamento_Real                                           1.000000
# Correlacao_Preco_Baixo_RealPreco_Corrigido_Real                                                 NaN
# Correlacao_Preco_Fechamento_RealPreco_Corrigido...                                              NaN
#
#                                                     Correlacao_Preco_Fechamento_RealPreco_Corrigido_Real
# Preco_Abertura_Petrobras                                                                          NaN
# Preco_Alta_Petrobras                                                                              NaN
# Preco_Baixo_Petrobras                                                                             NaN
# Preco_Fechamento_Petrobras                                                                        NaN
# Preco_Abertura_Petróleo                                                                           NaN
# Preco_Alta_Petróleo                                                                               NaN
# Preco_Baixo_Petróleo                                                                              NaN
# Preco_Fechamento_Petróleo                                                                         NaN
# Preco_Corrigido_Petróleo                                                                          NaN
# Preco_Abertura_Real                                                                               NaN
# Preco_Alta_Real                                                                                   NaN
# Preco_Baixo_Real                                                                                  NaN
# Preco_Fechamento_Real                                                                             NaN
# Preco_Corrigido_Real                                                                              NaN
# Preco_Abertura_Petrobras_Media                                                                    NaN
# Preco_Alta_Petrobras_Media                                                                        NaN
# Preco_Baixo_Petrobras_Media                                                                       NaN
# Preco_Fechamento_Petrobras_Media                                                                  NaN
# Preco_Abertura_Petróleo_Media                                                                     NaN
# Preco_Alta_Petróleo_Media                                                                         NaN
# Preco_Baixo_Petróleo_Media                                                                        NaN
# Preco_Fechamento_Petróleo_Media                                                                   NaN
# Preco_Corrigido_Petróleo_Media                                                                    NaN
# Preco_Abertura_Real_Media                                                                         NaN
# Preco_Alta_Real_Media                                                                             NaN
# Preco_Baixo_Real_Media                                                                            NaN
# Preco_Fechamento_Real_Media                                                                       NaN
# Preco_Corrigido_Real_Media                                                                        NaN
# Preco_Abertura_Petrobras_%                                                                        NaN
# Preco_Alta_Petrobras_%                                                                            NaN
# Preco_Baixo_Petrobras_%                                                                           NaN
# Preco_Fechamento_Petrobras_%                                                                      NaN
# Preco_Abertura_Petróleo_%                                                                         NaN
# Preco_Alta_Petróleo_%                                                                             NaN
# Preco_Baixo_Petróleo_%                                                                            NaN
# Preco_Fechamento_Petróleo_%                                                                       NaN
# Preco_Corrigido_Petróleo_%                                                                        NaN
# Preco_Abertura_Real_%                                                                             NaN
# Preco_Alta_Real_%                                                                                 NaN
# Preco_Baixo_Real_%                                                                                NaN
# Preco_Fechamento_Real_%                                                                           NaN
# Preco_Corrigido_Real_%                                                                            NaN
# Correlacao_Preco_Abertura_PetrobrasPreco_Alta_P...                                                NaN
# Correlacao_Preco_Abertura_PetrobrasPreco_Baixo_...                                                NaN
# Correlacao_Preco_Abertura_PetrobrasPreco_Fecham...                                                NaN
# Correlacao_Preco_Abertura_PetrobrasPreco_Abertu...                                                NaN
# Correlacao_Preco_Abertura_PetrobrasPreco_Alta_P...                                                NaN
# Correlacao_Preco_Abertura_PetrobrasPreco_Baixo_...                                                NaN
# Correlacao_Preco_Abertura_PetrobrasPreco_Fecham...                                                NaN
# Correlacao_Preco_Abertura_PetrobrasPreco_Corrig...                                                NaN
# Correlacao_Preco_Abertura_PetrobrasPreco_Abertu...                                                NaN
# Correlacao_Preco_Abertura_PetrobrasPreco_Alta_Real                                                NaN
# Correlacao_Preco_Abertura_PetrobrasPreco_Baixo_...                                                NaN
# Correlacao_Preco_Abertura_PetrobrasPreco_Fecham...                                                NaN
# Correlacao_Preco_Abertura_PetrobrasPreco_Corrig...                                                NaN
# Correlacao_Preco_Alta_PetrobrasPreco_Baixo_Petr...                                                NaN
# Correlacao_Preco_Alta_PetrobrasPreco_Fechamento...                                                NaN
# Correlacao_Preco_Alta_PetrobrasPreco_Abertura_P...                                                NaN
# Correlacao_Preco_Alta_PetrobrasPreco_Alta_Petróleo                                                NaN
# Correlacao_Preco_Alta_PetrobrasPreco_Baixo_Petr...                                                NaN
# Correlacao_Preco_Alta_PetrobrasPreco_Fechamento...                                                NaN
# Correlacao_Preco_Alta_PetrobrasPreco_Corrigido_...                                                NaN
# Correlacao_Preco_Alta_PetrobrasPreco_Abertura_Real                                                NaN
# Correlacao_Preco_Alta_PetrobrasPreco_Alta_Real                                                    NaN
# Correlacao_Preco_Alta_PetrobrasPreco_Baixo_Real                                                   NaN
# Correlacao_Preco_Alta_PetrobrasPreco_Fechamento...                                                NaN
# Correlacao_Preco_Alta_PetrobrasPreco_Corrigido_...                                                NaN
# Correlacao_Preco_Baixo_PetrobrasPreco_Fechament...                                                NaN
# Correlacao_Preco_Baixo_PetrobrasPreco_Abertura_...                                                NaN
# Correlacao_Preco_Baixo_PetrobrasPreco_Alta_Petr...                                                NaN
# Correlacao_Preco_Baixo_PetrobrasPreco_Baixo_Pet...                                                NaN
# Correlacao_Preco_Baixo_PetrobrasPreco_Fechament...                                                NaN
# Correlacao_Preco_Baixo_PetrobrasPreco_Corrigido...                                                NaN
# Correlacao_Preco_Baixo_PetrobrasPreco_Abertura_...                                                NaN
# Correlacao_Preco_Baixo_PetrobrasPreco_Alta_Real                                                   NaN
# Correlacao_Preco_Baixo_PetrobrasPreco_Baixo_Real                                                  NaN
# Correlacao_Preco_Baixo_PetrobrasPreco_Fechament...                                                NaN
# Correlacao_Preco_Baixo_PetrobrasPreco_Corrigido...                                                NaN
# Correlacao_Preco_Fechamento_PetrobrasPreco_Aber...                                                NaN
# Correlacao_Preco_Fechamento_PetrobrasPreco_Alta...                                                NaN
# Correlacao_Preco_Fechamento_PetrobrasPreco_Baix...                                                NaN
# Correlacao_Preco_Fechamento_PetrobrasPreco_Fech...                                                NaN
# Correlacao_Preco_Fechamento_PetrobrasPreco_Corr...                                                NaN
# Correlacao_Preco_Fechamento_PetrobrasPreco_Aber...                                                NaN
# Correlacao_Preco_Fechamento_PetrobrasPreco_Alta...                                                NaN
# Correlacao_Preco_Fechamento_PetrobrasPreco_Baix...                                                NaN
# Correlacao_Preco_Fechamento_PetrobrasPreco_Fech...                                                NaN
# Correlacao_Preco_Fechamento_PetrobrasPreco_Corr...                                                NaN
# Correlacao_Preco_Abertura_PetróleoPreco_Alta_Pe...                                                NaN
# Correlacao_Preco_Abertura_PetróleoPreco_Baixo_P...                                                NaN
# Correlacao_Preco_Abertura_PetróleoPreco_Fechame...                                                NaN
# Correlacao_Preco_Abertura_PetróleoPreco_Corrigi...                                                NaN
# Correlacao_Preco_Abertura_PetróleoPreco_Abertur...                                                NaN
# Correlacao_Preco_Abertura_PetróleoPreco_Alta_Real                                                 NaN
# Correlacao_Preco_Abertura_PetróleoPreco_Baixo_Real                                                NaN
# Correlacao_Preco_Abertura_PetróleoPreco_Fechame...                                                NaN
# Correlacao_Preco_Abertura_PetróleoPreco_Corrigi...                                                NaN
# Correlacao_Preco_Alta_PetróleoPreco_Baixo_Petróleo                                                NaN
# Correlacao_Preco_Alta_PetróleoPreco_Fechamento_...                                                NaN
# Correlacao_Preco_Alta_PetróleoPreco_Corrigido_P...                                                NaN
# Correlacao_Preco_Alta_PetróleoPreco_Abertura_Real                                                 NaN
# Correlacao_Preco_Alta_PetróleoPreco_Alta_Real                                                     NaN
# Correlacao_Preco_Alta_PetróleoPreco_Baixo_Real                                                    NaN
# Correlacao_Preco_Alta_PetróleoPreco_Fechamento_...                                                NaN
# Correlacao_Preco_Alta_PetróleoPreco_Corrigido_Real                                                NaN
# Correlacao_Preco_Baixo_PetróleoPreco_Fechamento...                                                NaN
# Correlacao_Preco_Baixo_PetróleoPreco_Corrigido_...                                                NaN
# Correlacao_Preco_Baixo_PetróleoPreco_Abertura_Real                                                NaN
# Correlacao_Preco_Baixo_PetróleoPreco_Alta_Real                                                    NaN
# Correlacao_Preco_Baixo_PetróleoPreco_Baixo_Real                                                   NaN
# Correlacao_Preco_Baixo_PetróleoPreco_Fechamento...                                                NaN
# Correlacao_Preco_Baixo_PetróleoPreco_Corrigido_...                                                NaN
# Correlacao_Preco_Fechamento_PetróleoPreco_Corri...                                                NaN
# Correlacao_Preco_Fechamento_PetróleoPreco_Abert...                                                NaN
# Correlacao_Preco_Fechamento_PetróleoPreco_Alta_...                                                NaN
# Correlacao_Preco_Fechamento_PetróleoPreco_Baixo...                                                NaN
# Correlacao_Preco_Fechamento_PetróleoPreco_Fecha...                                                NaN
# Correlacao_Preco_Fechamento_PetróleoPreco_Corri...                                                NaN
# Correlacao_Preco_Corrigido_PetróleoPreco_Abertu...                                                NaN
# Correlacao_Preco_Corrigido_PetróleoPreco_Alta_Real                                                NaN
# Correlacao_Preco_Corrigido_PetróleoPreco_Baixo_...                                                NaN
# Correlacao_Preco_Corrigido_PetróleoPreco_Fecham...                                                NaN
# Correlacao_Preco_Corrigido_PetróleoPreco_Corrig...                                                NaN
# Correlacao_Preco_Abertura_RealPreco_Alta_Real                                                     NaN
# Correlacao_Preco_Abertura_RealPreco_Baixo_Real                                                    NaN
# Correlacao_Preco_Abertura_RealPreco_Fechamento_...                                                NaN
# Correlacao_Preco_Abertura_RealPreco_Corrigido_Real                                                NaN
# Correlacao_Preco_Alta_RealPreco_Baixo_Real                                                        NaN
# Correlacao_Preco_Alta_RealPreco_Fechamento_Real                                                   NaN
# Correlacao_Preco_Alta_RealPreco_Corrigido_Real                                                    NaN
# Correlacao_Preco_Baixo_RealPreco_Fechamento_Real                                                  NaN
# Correlacao_Preco_Baixo_RealPreco_Corrigido_Real                                                   NaN
# Correlacao_Preco_Fechamento_RealPreco_Corrigido...                                                NaN
#
# [133 rows x 133 columns]

# %%
# Selecionar as colunas para deletar
to_drop = [column for column in upper.columns if any(upper[column] > 0.95)]

# %%
pb_petro_real = pb_petro_real.drop(columns=to_drop)

# %%
pb_petro_real['Dia_do_Ano'] = pb_petro_real.Data.apply(lambda x: x.dayofyear)
pb_petro_real['Semana_do_Ano'] = pb_petro_real.Data.apply(lambda x: x.weekofyear)

# %%
pb_petro_real['Preco_Acao_Fechamento'] = y
pb_petro_real.shape
# Out:
# (1244, 31)

# %%
data = pb_petro_real['Data']
del pb_petro_real['Data']

# %%
pb_petro_real = pb_petro_real.interpolate(method='linear', limit_direction='forward', axis=1)
pb_petro_real['Data'] = data

# %%
pb_petro_real.dropna(how='any', inplace = True)

# %%
pb_petro_real.shape
# Out:
# (1211, 31)

# %%
pb_petro_real.head()
# Out:
#     Preco_Abertura_Petrobras  Preco_Abertura_Petróleo  Preco_Abertura_Real  \
# 30                     12.35                56.869999             0.318900
# 31                     12.25                20.277778            28.305556
# 32                     11.51                54.900002             0.314600
# 33                     11.36                52.750000             0.310350
# 34                     11.62                52.910000             0.306750
#
#     Preco_Abertura_Petrobras_%  Preco_Abertura_Petróleo_%  \
# 30                    9.346144                  18.373388
# 31                   36.333333                  44.361111
# 32                    9.502016                  18.689432
# 33                    9.537936                  18.765522
# 34                    9.574480                  18.842210
#
#     Preco_Baixo_Petróleo_%  Preco_Abertura_Real_%  \
# 30               27.400632              36.427876
# 31               52.388889              60.416667
# 32               27.876848              37.064264
# 33               27.993108              37.220694
# 34               28.109940              37.377670
#
#     Correlacao_Preco_Abertura_PetrobrasPreco_Alta_Petrobras  \
# 30                                          45.455120
# 31                                          68.444444
# 32                                          46.251680
# 33                                          46.448280
# 34                                          46.645400
#
#     Correlacao_Preco_Abertura_PetrobrasPreco_Baixo_Petrobras  \
# 30                                          54.482364
# 31                                          76.472222
# 32                                          55.439096
# 33                                          55.675866
# 34                                          55.913130
#
#     Correlacao_Preco_Abertura_PetrobrasPreco_Fechamento_Petrobras  ...  \
# 30                                          63.509608              ...
# 31                                          84.500000              ...
# 32                                          64.626512              ...
# 33                                          64.903452              ...
# 34                                          65.180860              ...
#
#     Correlacao_Preco_Fechamento_PetróleoPreco_Corrigido_Petróleo  \
# 30                                         171.836536
# 31                                         180.833333
# 32                                         174.875504
# 33                                         175.634484
# 34                                         176.393620
#
#     Correlacao_Preco_Abertura_RealPreco_Alta_Real  \
# 30                                     180.863780
# 31                                     188.861111
# 32                                     184.062920
# 33                                     184.862070
# 34                                     185.661350
#
#     Correlacao_Preco_Abertura_RealPreco_Baixo_Real  \
# 30                                      189.891024
# 31                                      196.888889
# 32                                      193.250336
# 33                                      194.089656
# 34                                      194.929080
#
#     Correlacao_Preco_Abertura_RealPreco_Fechamento_Real  \
# 30                                         198.918268
# 31                                         204.916667
# 32                                         202.437752
# 33                                         203.317242
# 34                                         204.196810
#
#     Correlacao_Preco_Alta_RealPreco_Baixo_Real  \
# 30                                  207.945512
# 31                                  212.944444
# 32                                  211.625168
# 33                                  212.544828
# 34                                  213.464540
#
#     Correlacao_Preco_Fechamento_RealPreco_Corrigido_Real  Dia_do_Ano  \
# 30                                         216.972756          226.0
# 31                                         220.972222          229.0
# 32                                         220.812584          230.0
# 33                                         221.772414          231.0
# 34                                         222.732270          232.0
#
#     Semana_do_Ano  Preco_Acao_Fechamento       Data
# 30           33.0               8.627806 2015-08-14
# 31           34.0               8.488647 2015-08-17
# 32           34.0               8.340212 2015-08-18
# 33           34.0               8.108282 2015-08-19
# 34           34.0               8.061894 2015-08-20
#
# [5 rows x 31 columns]

# %%
pb_petro_real['Data'].min()
# Out:
# Timestamp('2015-08-14 00:00:00')

# %%
pb_petro_real['Data'].max()
# Out:
# Timestamp('2020-07-01 00:00:00')

# %%
pb_petro_real['Ano'] = pb_petro_real['Data'].dt.year
pb_petro_real['Mes'] = pb_petro_real['Data'].dt.month
pb_petro_real['Dia'] = pb_petro_real['Data'].dt.day

# %%
#Listas para salvar as métricas e parâmetros
parametros = []
metricas = []

val = []
pred = []

data = []

# %%
data1 = ['2015-10-01', '2015-11-01', '2015-12-01', '2016-01-01',
         '2016-02-01',  '2016-03-01', '2016-04-01', 
        '2016-05-01', '2016-06-01', '2016-07-01', '2016-08-01'
        , '2016-09-01', '2016-10-01', '2016-11-01']

data2 = ['2018-10-01', '2018-11-01', '2018-12-01','2019-01-01',
         '2019-02-01', '2019-03-01', '2019-04-01', 
        '2019-05-01',  '2019-06-01',  '2019-07-01', '2019-08-01'
         '2019-09-01', '2019-10-01', '2019-11-01']

data3 = [ '2018-11-01', '2018-12-01', '2019-01-01',
        '2019-02-01', '2019-03-01', '2019-04-01', '2019-05-01',
        '2019-06-01', '2019-07-10', '2019-08-01'
        ,'2019-09-01', '2019-10-01',  '2019-11-01', '2019-12-01']

data4 = ['2018-12-01', '2019-01-01', '2019-02-01',
        '2019-03-01', '2019-04-01', '2019-05-01',
        '2019-06-01', '2019-07-01', '2019-08-01', '2019-09-01'
        ,'2019-10-01', '2019-11-01', '2019-12-01', '2020-01-01']

# %%
len(data1)
# Out:
# 14

# %%
for i in range (0, 10):

    #treino
    treino = pb_petro_real.loc[(pb_petro_real['Data']>=data1[i]) & (pb_petro_real['Data'] < data2[i])]
    y_treino = treino['Preco_Acao_Fechamento'].values
    data_treino = treino ['Data']
    del treino['Preco_Acao_Fechamento']
    del treino ['Data']

    #validação
    validacao = pb_petro_real.loc[(pb_petro_real['Data']>=data2[i]) & (pb_petro_real['Data'] < data3[i])]
    y_validacao = validacao['Preco_Acao_Fechamento'].values
    data_validacao = validacao['Data']
    del validacao['Preco_Acao_Fechamento']
    del validacao ['Data']
    
    #teste
    teste = pb_petro_real.loc[(pb_petro_real['Data']>=data3[i]) & (pb_petro_real['Data'] < data4[i])]
    y_teste = teste['Preco_Acao_Fechamento'].values
    data_teste = teste ['Data']
    del teste['Preco_Acao_Fechamento']
    del teste ['Data']

    
#    if teste.shape[0] >= 5:
#        if validacao.shape[0] >= 5:
    lgb_train = lgb.Dataset(treino.values, y_treino)
    lgb_eval = lgb.Dataset(validacao.values, y_validacao, reference=lgb_train)

    def objective(trial):

            # 2. Suggest values of the hyperparameters using a trial object.
            param = {
                'objective': 'regression',
                'metric': 'mse',
                'boosting_type': trial.suggest_categorical("boosting_type", ["gbdt", "dart"]),
                'num_leaves': trial.suggest_int('num_leaves', 2, 256),
                'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
                'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
                'bagging_freq': trial.suggest_int('bagging_freq', 1, 7),
                'min_child_samples': trial.suggest_int('min_child_samples', 5, 100),
                'max_depth': trial.suggest_int('max_depth', 5, 100),
            }

            gbm = lgb.train(param, lgb_train)
            y_pred = gbm.predict(validacao.values)
            rmse = mean_squared_error(y_validacao, y_pred) ** 0.5
            return rmse

    study = optuna.create_study(direction='minimize')
    study.optimize(objective, n_trials=30)

    final_model = lgb.LGBMRegressor(**study.best_params)
    y_pred2 = final_model.fit(treino.values, y_treino).predict(teste)

    rmse = mean_squared_error(y_teste ,y_pred2) ** 0.5
    print(rmse)

    parametros.append(study.best_params)
    metricas.append(rmse)
    val.append(y_validacao)
    pred.append(y_pred2)
    data.append(data_validacao)
# Out:
# [I 2020-07-02 22:02:13,860] Finished trial#0 with value: 6.54442792999266 with parameters: {'boosting_type': 'gbdt', 'num_leaves': 251, 'feature_fraction': 0.41558816535668436, 'bagging_fraction': 0.8419383314379572, 'bagging_freq': 2, 'min_child_samples': 79, 'max_depth': 65}. Best is trial#0 with value: 6.54442792999266.
# [I 2020-07-02 22:02:14,260] Finished trial#1 with value: 8.486006438091518 with parameters: {'boosting_type': 'dart', 'num_leaves': 187, 'feature_fraction': 0.8495279856758382, 'bagging_fraction': 0.6541765435503608, 'bagging_freq': 3, 'min_child_samples': 46, 'max_depth': 56}. Best is trial#0 with value: 6.54442792999266.
# [I 2020-07-02 22:02:14,592] Finished trial#2 with value: 6.819767520537571 with parameters: {'boosting_type': 'gbdt', 'num_leaves': 92, 'feature_fraction': 0.9619286916498669, 'bagging_fraction': 0.5655404932193057, 'bagging_freq': 7, 'min_child_samples': 98, 'max_depth': 59}. Best is trial#0 with value: 6.54442792999266.
# [I 2020-07-02 22:02:14,901] Finished trial#3 with value: 6.3668630242964115 with parameters: {'boosting_type': 'gbdt', 'num_leaves': 117, 'feature_fraction': 0.40807927409264205, 'bagging_fraction': 0.7793128072587829, 'bagging_freq': 6, 'min_child_samples': 72, 'max_depth': 59}. Best is trial#3 with value: 6.3668630242964115.
# [I 2020-07-02 22:02:15,210] Finished trial#4 with value: 8.048158091132574 with parameters: {'boosting_type': 'dart', 'num_leaves': 150, 'feature_fraction': 0.9480461715388251, 'bagging_fraction': 0.8889290620247406, 'bagging_freq': 6, 'min_child_samples': 74, 'max_depth': 18}. Best is trial#3 with value: 6.3668630242964115.
# [I 2020-07-02 22:02:15,631] Finished trial#5 with value: 6.566763292933757 with parameters: {'boosting_type': 'gbdt', 'num_leaves': 206, 'feature_fraction': 0.984892342054087, 'bagging_fraction': 0.6296022072910529, 'bagging_freq': 2, 'min_child_samples': 25, 'max_depth': 72}. Best is trial#3 with value: 6.3668630242964115.
# [I 2020-07-02 22:02:15,969] Finished trial#6 with value: 8.3747577424089 with parameters: {'boosting_type': 'dart', 'num_leaves': 160, 'feature_fraction': 0.5415660378460572, 'bagging_fraction': 0.7272133549512663, 'bagging_freq': 3, 'min_child_samples': 58, 'max_depth': 69}. Best is trial#3 with value: 6.3668630242964115.
# [I 2020-07-02 22:02:16,334] Finished trial#7 with value: 8.798201647449176 with parameters: {'boosting_type': 'dart', 'num_leaves': 33, 'feature_fraction': 0.9363721333282972, 'bagging_fraction': 0.6040212764625245, 'bagging_freq': 2, 'min_child_samples': 32, 'max_depth': 54}. Best is trial#3 with value: 6.3668630242964115.
# [I 2020-07-02 22:02:16,728] Finished trial#8 with value: 8.083725662796626 with parameters: {'boosting_type': 'dart', 'num_leaves': 17, 'feature_fraction': 0.7171626923360848, 'bagging_fraction': 0.6600689726622673, 'bagging_freq': 6, 'min_child_samples': 27, 'max_depth': 44}. Best is trial#3 with value: 6.3668630242964115.
# [I 2020-07-02 22:02
with parameters: {'boosting_type': 'gbdt', 'num_leaves': 75, 'feature_fraction': 0.48068834466044574, 'bagging_fraction': 0.966954068879086, 'bagging_freq': 2, 'min_child_samples': 79, 'max_depth': 90}. Best is trial#14 with value: 1.1180357284269995.
# [I 2020-07-02 22:03:06,977] Finished trial#28 with value: 2.119711812294306 with parameters: {'boosting_type': 'gbdt', 'num_leaves': 143, 'feature_fraction': 0.5913972421109005, 'bagging_fraction': 0.7996062849539192, 'bagging_freq': 3, 'min_child_samples': 48, 'max_depth': 50}. Best is trial#14 with value: 1.1180357284269995.
# [I 2020-07-02 22:03:07,576] Finished trial#29 with value: 1.8666609716734437 with parameters: {'boosting_type': 'dart', 'num_leaves': 26, 'feature_fraction': 0.6597984777832476, 'bagging_fraction': 0.9027562994346003, 'bagging_freq': 2, 'min_child_samples': 37, 'max_depth': 75}. Best is trial#14 with value: 1.1180357284269995.
# 8.020857867409791
# [I 2020-07-02 22:03:08,287] Finished trial#0 with value: 9.802935485163873 with parameters: {'boosting_type': 'dart', 'num_leaves': 21, 'feature_fraction': 0.9134607136025376, 'bagging_fraction': 0.44556782945248785, 'bagging_freq': 2, 'min_child_samples': 95, 'max_depth': 89}. Best is trial#0 with value: 9.802935485163873.
# [I 2020-07-02 22:03:08,733] Finished trial#1 with value: 10.480033302451895 with parameters: {'boosting_type': 'dart', 'num_leaves': 61, 'feature_fraction': 0.4238097286020854, 'bagging_fraction': 0.7022262043919718, 'bagging_freq': 3, 'min_child_samples': 62, 'max_depth': 59}. Best is trial#0 with value: 9.802935485163873.
# [I 2020-07-02 22:03:09,141] Finished trial#2 with value: 8.706206149943203 with parameters: {'boosting_type': 'gbdt', 'num_leaves': 132, 'feature_fraction': 0.6633439695777765, 'bagging_fraction': 0.46592080272876935, 'bagging_freq': 1, 'min_child_samples': 47, 'max_depth': 48}. Best is trial#2 with value: 8.706206149943203.
# [I 2020-07-02 22:03:09,672] Finished trial#3 with value: 10.279168412864008 with parameters: {'boosting_type': 'dart', 'num_leaves': 180, 'feature_fraction': 0.6620086902853044, 'bagging_fraction': 0.9627029725082586, 'bagging_freq': 2, 'min_child_samples': 77, 'max_depth': 87}. Best is trial#2 with value: 8.706206149943203.
# [I 2020-07-02 22:03:10,223] Finished trial#4 with value: 9.30490615415097 with parameters: {'boosting_type': 'dart', 'num_leaves': 27, 'feature_fraction': 0.7762756770849115, 'bagging_fraction': 0.9990895442358224, 'bagging_freq': 4, 'min_child_samples': 59, 'max_depth': 72}. Best is trial#2 with value: 8.706206149943203.
# [I 2020-07-02 22:03:10,705] Finished trial#5 with value: 8.231466356527916 with parameters: {'boosting_type': 'gbdt', 'num_leaves': 140, 'feature_fraction': 0.479630310164793, 'bagging_fraction': 0.9230790152165818, 'bagging_freq': 2, 'min_child_samples': 49, 'max_depth': 28}. Best is trial#5 with value: 8.231466356527916.
# [I 2020-07-02 22:03:11,134] Finished trial#6 with value: 10.054579594235605 with parameters: {'boosting_type': 'dart', 'num_leaves': 189, 'feature_fraction': 0.7779506155938463, 'bagging_fraction': 0.6969895757943956, 'bagging_freq': 1, 'min_child_samples': 65, 'max_depth': 88}. Best is trial#5 with value: 8.231466356527916.
# [I 2020-07-02 22:03:11,480] Finished trial#7 with value: 9.685286944649723 with parameters: {'boosting_type': 'dart', 'num_leaves': 29, 'feature_fraction': 0.7800257558379142, 'bagging_fraction': 0.7168553940477773, 'bagging_freq': 2, 'min_child_samples': 96, 'max_depth': 26}. Best is trial#5 with value: 8.231466356527916.
. Best is trial#1 with value: 1.3619419408727151.
# [I 2020-07-02 22:04:49,462] Finished trial#28 with value: 2.0160478343366983 with parameters: {'boosting_type': 'gbdt', 'num_leaves': 78, 'feature_fraction': 0.86645325249962, 'bagging_fraction': 0.5132251044653175, 'bagging_freq': 3, 'min_child_samples': 48, 'max_depth': 29}. Best is trial#1 with value: 1.3619419408727151.
# [I 2020-07-02 22:04:49,741] Finished trial#29 with value: 1.5369274648090627 with parameters: {'boosting_type': 'gbdt', 'num_leaves': 98, 'feature_fraction': 0.9379398217847716, 'bagging_fraction': 0.7534442675493263, 'bagging_freq': 6, 'min_child_samples': 76, 'max_depth': 89}. Best is trial#1 with value: 1.3619419408727151.
# 1.0794897857965882

# %%
metricas
# Out:
# [6.012971854088638,
#  1.4082695913615793,
#  8.020857867409791,
#  6.637847960384765,
#  5.454539821857647,
#  2.2255773728131403,
#  1.3380753495753088,
#  2.6781429763922238,
#  2.4445208036355655,
#  1.0794897857965882]

# %%
np.argmin(metricas)
# Out:
# 9

# %%
print(len(parametros))
print(parametros[np.argmin(metricas)])
# Out:
# 10
# {'boosting_type': 'gbdt', 'num_leaves': 68, 'feature_fraction': 0.9939114890219161, 'bagging_fraction': 0.9506203616587963, 'bagging_freq': 4, 'min_child_samples': 28, 'max_depth': 98}

# %%
final_model = lgb.LGBMRegressor(**parametros[np.argmin(metricas)])
final_model.fit(treino.values, y_treino)
y_val_pred = final_model.predict(validacao)
y_test_pred = final_model.predict(teste)

# %%
y_real = np.concatenate([y_treino, y_validacao, y_teste])
y_prd = np.concatenate([y_treino, y_val_pred, y_test_pred])
data = np.concatenate([data_treino, data_validacao, data_teste])

# %%
plt.figure(figsize=(20,10))
plt.plot(data,y_real)
plt.plot(y_prd)
# Out:
# [<matplotlib.lines.Line2D object at 0x000001CFC036B0D0>]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\Anaconda3\envs\time_series\lib\site-packages\ipykernel\pylab\backend_inline.py in show(close, block)
#      41             display(
#      42                 figure_manager.canvas.figure,
# ---> 43                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      44             )
#      45     finally:
#
# ~\Anaconda3\envs\time_series\lib\site-packages\ipykernel\pylab\backend_inline.py in _fetch_figure_metadata(fig)
#     178     if _is_transparent(fig.get_facecolor()):
#     179         # the background is transparent
# --> 180         ticksLight = _is_light([label.get_color()
#     181                                 for axes in fig.axes
#     182                                 for axis in (axes.xaxis, axes.yaxis)
#
# ~\Anaconda3\envs\time_series\lib\site-packages\ipykernel\pylab\backend_inline.py in <listcomp>(.0)
#     181                                 for axes in fig.axes
#     182                                 for axis in (axes.xaxis, axes.yaxis)
# --> 183                                 for label in axis.get_ticklabels()])
#     184         if ticksLight.size and (ticksLight == ticksLight[0]).all():
#     185             # there are one or more tick labels, all with the same lightness
#
# ~\Anaconda3\envs\time_series\lib\site-packages\matplotlib\axis.py in get_ticklabels(self, minor, which)
#    1318         if minor:
#    1319             return self.get_minorticklabels()
# -> 1320         return self.get_majorticklabels()
#    1321
#    1322     def get_majorticklines(self):
#
# ~\Anaconda3\envs\time_series\lib\site-packages\matplotlib\axis.py in get_majorticklabels(self)
#    1274     def get_majorticklabels(self):
#    1275         'Return a list of Text instances for the major ticklabels.'
# -> 1276         ticks = self.get_major_ticks()
#    1277         labels1 = [tick.label1 for tick in ticks if tick.label1.get_visible()]
#    1278         labels2 = [tick.label2 for tick in ticks if tick.label2.get_visible()]
#
# ~\Anaconda3\envs\time_series\lib\site-packages\matplotlib\axis.py in get_major_ticks(self, numticks)
#    1429         'Get the tick instances; grow as necessary.'
#    1430         if numticks is None:
# -> 1431             numticks = len(self.get_majorticklocs())
#    1432
#    1433         while len(self.majorTicks) < numticks:
#
# ~\Anaconda3\envs\time_series\lib\site-packages\matplotlib\axis.py in get_majorticklocs(self)
#    1346     def get_majorticklocs(self):
#    1347         """Get the array of major tick locations in data coordinates."""
# -> 1348         return self.major.locator()
#    1349
#    1350     def get_minorticklocs(self):
#
# ~\Anaconda3\envs\time_series\lib\site-packages\matplotlib\dates.py in __call__(self)
#    1336     def __call__(self):
#    1337         'Return the locations of the ticks'
# -> 1338         self.refresh()
#    1339         return self._locator()
#    1340
#
# ~\Anaconda3\envs\time_series\lib\site-packages\matplotlib\dates.py in refresh(self)
#    1362     def refresh(self):
#    1363         # docstring inherited
# -> 1364         dmin, dmax = self.viewlim_to_dt()
#    1365         self._locator = self.get_locator(dmin, dmax)
#    1366
#
# ~\Anaconda3\envs\time_series\lib\site-packages\matplotlib\dates.py in viewlim_to_dt(self)
#    1092             vmin, vmax = vmax, vmin
#    1093         if vmin < 1:
# -> 1094             raise ValueError('view limit minimum {} is less than 1 and '
#    1095                              'is an invalid Matplotlib date value. This '
#    1096                              'often happens if you pass a non-datetime '
#
# ValueError: view limit minimum -36865.05 is less than 1 and is an invalid Matplotlib date value. This often happens if you pass a non-datetime value to an axis that has datetime units
